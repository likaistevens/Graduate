# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName('DT').getOrCreate()

# %%
df = spark.read.format("csv").option("sep",",").option("inferSchema","true").option("header","true").load("test2_score.txt")
df.printSchema()
# Out:
# root
#  |-- Userid: integer (nullable = true)
#  |-- label: integer (nullable = true)
#  |-- trackid: integer (nullable = true)
#  |-- albumscore: integer (nullable = true)
#  |-- artistscore: integer (nullable = true)
#  |-- genreamax: integer (nullable = true)
#  |-- genreamin: integer (nullable = true)
#  |-- genreamean: double (nullable = true)

# %%
import pandas as pd
pd.DataFrame(df.take(5), columns=df.columns).transpose()
numeric_features = ['Userid','trackid','label','albumscore','artistscore','genreamax','genreamin','genreamean']

df.select(numeric_features).describe().toPandas().transpose()
# Out:
#                  0                   1                   2       3       4
# summary      count                mean              stddev     min     max
# Userid        6000          206286.491   3515.749299951101  200031  212234
# trackid       6000         149260.0025   86146.45891885243      65  296098
# label         6000                 0.5  0.5000416718757232       0       1
# albumscore    6000                 0.0                 0.0       0       0
# artistscore   6000  23.488666666666667   38.63689523198974       0     100
# genreamax     6000   48.80733333333333   43.19745227289881       0     100
# genreamin     6000  42.272333333333336  40.789456944842996       0     100
# genreamean    6000   45.58248076923077   41.17219269010034     0.0   100.0

# %%
# import matplotlib.pyplot as plt
# numeric_data = df.select(numeric_features).toPandas()

# axs = pd.plotting.scatter_matrix(numeric_data, figsize=(8, 8));
# n = len(numeric_data.columns)
# for i in range(n):
#     v = axs[i, 0]
#     v.yaxis.label.set_rotation(0)
#     v.yaxis.label.set_ha("right")
#     v.set_yticks(())
#     h = axs[n-1, i]
#     h.xaxis.label.set_rotation(90)
#     h.set_xticks(())
# plt.show()

# %%
from pyspark.ml.feature import VectorAssembler
import pyspark.sql.types as types
df=df.withColumn('label',df['label'].cast(types.IntegerType()))
df=df.withColumn('Userid',df['Userid'].cast(types.IntegerType()))
df=df.withColumn('trackid',df['trackid'].cast(types.IntegerType()))
df=df.withColumn('albumscore',df['albumscore'].cast(types.IntegerType()))
df=df.withColumn('artistscore',df['artistscore'].cast(types.IntegerType()))
df=df.withColumn('genreamax',df['genreamax'].cast(types.IntegerType()))
df=df.withColumn('genreamin',df['genreamin'].cast(types.IntegerType()))
df=df.withColumn('genreamean',df['genreamean'].cast(types.IntegerType()))

assembler=VectorAssembler(inputCols=['Userid','trackid','label','artistscore','genreamax','genreamin','genreamean'],outputCol='features')

# %%
from pyspark.ml import Pipeline
pipeline=Pipeline(stages=[assembler])
model=pipeline.fit(df)
df=model.transform(df)

# %%
from pyspark.ml.classification import GBTClassifier
gbt = GBTClassifier(featuresCol = 'features',maxIter=10)
gbtModel = gbt.fit(df)

# %%
df1 = spark.read.format("csv").option("sep",",").option("inferSchema","true").option("header","true").load("test_02 copy.txt")
df1.printSchema()
# Out:
# root
#  |-- Userid: integer (nullable = true)
#  |-- label: integer (nullable = true)
#  |-- trackid: integer (nullable = true)
#  |-- albumscore: integer (nullable = true)
#  |-- artistscore: integer (nullable = true)
#  |-- genreamax: integer (nullable = true)
#  |-- genreamin: integer (nullable = true)
#  |-- genreamean: double (nullable = true)

# %%
import pandas as pd
pd.DataFrame(df1.take(5), columns=df1.columns).transpose()
numeric_features = ['Userid','trackid','label','albumscore','artistscore','genreamax','genreamin','genreamean']

df1.select(numeric_features).describe().toPandas().transpose()
# Out:
#                   0                   1                   2       3       4
# summary       count                mean              stddev     min     max
# Userid       120000         224372.7714  14155.612277030812  199810  249010
# trackid      120000  147871.92235833334    85421.1993529344       1  296099
# label        120000                 0.0                 0.0       0       0
# albumscore   120000           23.685075  38.767846279190096       0     100
# artistscore  120000           35.016175   42.73300263592536       0     100
# genreamax    120000  35.471716666666666   40.80419698479321       0     100
# genreamin    120000   32.74715833333333   39.44356509895082       0     100
# genreamean   120000  34.149823609307354   39.70187105524825     0.0   100.0

# %%
from pyspark.ml.feature import VectorAssembler
import pyspark.sql.types as types
df1=df1.withColumn('label',df1['label'].cast(types.IntegerType()))
df1=df1.withColumn('Userid',df1['Userid'].cast(types.IntegerType()))
df1=df1.withColumn('trackid',df1['trackid'].cast(types.IntegerType()))
df1=df1.withColumn('albumscore',df1['albumscore'].cast(types.IntegerType()))
df1=df1.withColumn('artistscore',df1['artistscore'].cast(types.IntegerType()))
df1=df1.withColumn('genreamax',df1['genreamax'].cast(types.IntegerType()))
df1=df1.withColumn('genreamin',df1['genreamin'].cast(types.IntegerType()))
df1=df1.withColumn('genreamean',df1['genreamean'].cast(types.IntegerType()))

assembler1=VectorAssembler(inputCols=['Userid','trackid','label','artistscore','genreamax','genreamin','genreamean'],outputCol='features')

# %%
from pyspark.ml import Pipeline
pipeline=Pipeline(stages=[assembler1])
model1=pipeline.fit(df1)
df1=model1.transform(df1)

# %%
predictions1 = gbtModel.transform(df1)
predictions1.show(10)
# Out:
# +------+-----+-------+----------+-----------+---------+---------+----------+--------------------+--------------------+--------------------+----------+
# |Userid|label|trackid|albumscore|artistscore|genreamax|genreamin|genreamean|            features|       rawPrediction|         probability|prediction|
# +------+-----+-------+----------+-----------+---------+---------+----------+--------------------+--------------------+--------------------+----------+
# |199810|    0| 208019|         0|          0|        0|        0|         0|(7,[0,1],[199810....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199810|    0|  74139|         0|          0|       80|       80|        80|[199810.0,74139.0...|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199810|    0|   9903|         0|          0|        0|        0|         0|(7,[0,1],[199810....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199810|    0| 242681|         0|          0|        0|        0|         0|(7,[0,1],[199810....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199810|    0|  18515|         0|         70|        0|        0|         0|(7,[0,1,3],[19981...|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199810|    0| 105760|         0|         90|       80|       80|        80|[199810.0,105760....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199812|    0| 276940|         0|          0|        0|        0|         0|(7,[0,1],[199812....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199812|    0| 142408|       100|        100|       80|       80|        80|[199812.0,142408....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199812|    0| 130023|       100|        100|       80|       80|        80|[199812.0,130023....|[1.32590267922033...|[0.93412217565278...|       0.0|
# |199812|    0|  29189|         0|          0|       80|       80|        80|[199812.0,29189.0...|[1.32590267922033...|[0.93412217565278...|       0.0|
# +------+-----+-------+----------+-----------+---------+---------+----------+--------------------+--------------------+--------------------+----------+
# only showing top 10 rows

# %%
predictions1.count()
# Out:
# 120000

# %%
pre=predictions1.rdd.map(lambda x: x.prediction).collect()

# %%
prob=predictions1.rdd.map(lambda x: x.probability).collect()

# %%
user=predictions1.rdd.map(lambda x: x.Userid).collect()

# %%
track=predictions1.rdd.map(lambda x: x.trackid).collect()

# %%
track
# Out:
# [208019,
#  74139,
#  9903,
#  242681,
#  18515,
#  105760,
#  276940,
#  142408,
#  130023,
#  29189,
#  223706,
#  211361,
#  188441,
#  20968,
#  21571,
#  79640,
#  184173,
#  111874,
#  122375,
#  189043,
#  122429,
#  52519,
#  232332,
#  262193,
#  64345,
#  118841,
#  275682,
#  30062,
#  258473,
#  129866,
#  274758,
#  102153,
#  183464,
#  23616,
#  81699,
#  46627,
#  83722,
#  200166,
#  148603,
#  88745,
#  144775,
#  222966,
#  141875,
#  290905,
#  59789,
#  283698,
#  106788,
#  235999,
#  202308,
#  36793,
#  247549,
#  214280,
#  123424,
#  193003,
#  235240,
#  292341,
#  126082,
#  142163,
#  20067,
#  286335,
#  231569,
#  51933,
#  16949,
#  34642,
#  229894,
#  42811,
#  47402,
#  21317,
#  185734,
#  92685,
#  110099,
#  33495,
#  21593,
#  132124,
#  170625,
#  30365,
#  143570,
#  254625,
#  281826,
#  253265,
#  48891,
#  33980,
#  207963,
#  126528,
#  48808,
#  223958,
#  179298,
#  5121,
#  31975,
#  38775,
#  92599,
#  75369,
#  184197,
#  183841,
#  197936,
#  138391,
#  36027,
#  29249,
#  221237,
#  123579,
#  19694,
#  255036,
#  6143,
#  24607,
#  95726,
#  46697,
#  256209,
#  266780,
#  7477,
#  266143,
#  291820,
#  196470,
#  263222,
#  225097,
#  77700,
#  138272,
#  140229,
#  43472,
#  118108,
#  81165,
#  189985,
#  31440,
#  169945,
#  95594,
#  238400,
#  100669,
#  273378,
#  19705,
#  20499,
#  101984,
#  214726,
#  61792,
#  44444,
#  39446,
#  282901,
#  63072,
#  19595,
#  127769,
#  54037,
#  89981,
#  256134,
#  213546,
#  222196,
#  161111,
#  226277,
#  92910,
#  214592,
#  20999,
#  154755,
#  228397,
#  252693,
#  69487,
#  24631,
#  50032,
#  277150,
#  4836,
#  142462,
#  255065,
#  85596,
#  269486,
#  30595,
#  37731,
#  22400,
#  105128,
#  2877,
#  51667,
#  289911,
#  17,
#  192584,
#  56525,
#  94381,
#  249701,
#  127111,
#  77154,
#  80123,
#  108161,
#  179298,
#  280411,
#  196729,
#  225847,
#  222604,
#  126413,
#  144718,
#  241999,
#  184020,
#  249930,
#  142729,
#  117929,
#  252600,
#  125126,
#  46889,
#  291314,
#  24085,
#  80589,
#  79604,
#  218286,
#  122067,
#  257899,
#  8379,
#  217580,
#  65230,
#  65855,
#  241597,
#  187050,
#  257097,
#  277360,
#  69317,
#  47894,
#  102449,
#  267088,
#  266143,
#  224615,
#  154327,
#  14107,
#  22640,
#  133341,
#  146575,
#  192238,
#  109824,
#  125958,
#  79309,
#  42782,
#  36155,
#  5444,
#  150640,
#  155463,
#  247800,
#  152366,
#  134307,
#  255399,
#  155743,
#  151269,
#  200432,
#  87913,
#  114634,
#  151926,
#  190001,
#  286440,
#  48289,
#  141713,
#  32135,
#  244657,
#  117789,
#  45103,
#  279606,
#  280110,
#  279067,
#  15811,
#  250006,
#  31746,
#  251949,
#  9592,
#  195551,
#  69797,
#  59891,
#  249919,
#  229468,
#  276415,
#  175151,
#  101756,
#  222456,
#  183890,
#  42748,
#  59296,
#  30902,
#  54300,
#  46394,
#  236744,
#  40880,
#  210352,
#  219739,
#  287949,
#  23822,
#  44210,
#  261886,
#  110099,
#  111243,
#  124466,
#  263958,
#  249140,
#  298,
#  127445,
#  64481,
#  61826,
#  54636,
#  52391,
#  172050,
#  78355,
#  152843,
#  23252,
#  170920,
#  21878,
#  50179,
#  229538,
#  252021,
#  125831,
#  233293,
#  286721,
#  87357,
#  188926,
#  284745,
#  137479,
#  94531,
#  295555,
#  262472,
#  78278,
#  118642,
#  252839,
#  232361,
#  11535,
#  266171,
#  29554,
#  251164,
#  114265,
#  103426,
#  138333,
#  150958,
#  242417,
#  237580,
#  138590,
#  77933,
#  247578,
#  144100,
#  106344,
#  48891,
#  175928,
#  143902,
#  95242,
#  198864,
#  76816,
#  108161,
#  16078,
#  120535,
#  54651,
#  49904,
#  62568,
#  142473,
#  180224,
#  73940,
#  44783,
#  139444,
#  41368,
#  137693,
#  87125,
#  171481,
#  251278,
#  65142,
#  215837,
#  140334,
#  90442,
#  161183,
#  242657,
#  149874,
#  122518,
#  131954,
#  68360,
#  119027,
#  284320,
#  104542,
#  2924,
#  222840,
#  18198,
#  37960,
#  250816,
#  170214,
#  44222,
#  32596,
#  12969,
#  216902,
#  89110,
#  71574,
#  245276,
#  20538,
#  151964,
#  171735,
#  163166,
#  95326,
#  270004,
#  111062,
#  223859,
#  165847,
#  245574,
#  171700,
#  12922,
#  135759,
#  261128,
#  220067,
#  191060,
#  45668,
#  92843,
#  67182,
#  281157,
#  18733,
#  166911,
#  181496,
#  118642,
#  107099,
#  99698,
#  196040,
#  52853,
#  19388,
#  163568,
#  157403,
#  262177,
#  187117,
#  73710,
#  157478,
#  48583,
#  44782,
#  75676,
#  144640,
#  277674,
#  85063,
#  92599,
#  264558,
#  224104,
#  267631,
#  152820,
#  99223,
#  111277,
#  248267,
#  202112,
#  7740,
#  263828,
#  37057,
#  43391,
#  72011,
#  85844,
#  17790,
#  12010,
#  203948,
#  44094,
#  14689,
#  39799,
#  39602,
#  38287,
#  63433,
#  250006,
#  202739,
#  214979,
#  2843,
#  132003,
#  183159,
#  222425,
#  94498,
#  85844,
#  17907,
#  6173,
#  156103,
#  4310,
#  9810,
#  143588,
#  257449,
#  39447,
#  204267,
#  172907,
#  295907,
#  10628,
#  286329,
#  73886,
#  70203,
#  282197,
#  125958,
#  138333,
#  63855,
#  88123,
#  188301,
#  116957,
#  293108,
#  211659,
#  61827,
#  12127,
#  153742,
#  281844,
#  244686,
#  190154,
#  206026,
#  260780,
#  142675,
#  154382,
#  220973,
#  79550,
#  183431,
#  114059,
#  120535,
#  189306,
#  240746,
#  163720,
#  6330,
#  47483,
#  4102,
#  245818,
#  199756,
#  66754,
#  268182,
#  197751,
#  135194,
#  254703,
#  174481,
#  133167,
#  184197,
#  145221,
#  70738,
#  48244,
#  108560,
#  152985,
#  200612,
#  18684,
#  32651,
#  247852,
#  75564,
#  154321,
#  61539,
#  44110,
#  237168,
#  58813,
#  210679,
#  5791,
#  233951,
#  12756,
#  37154,
#  215013,
#  28885,
#  245668,
#  66741,
#  61924,
#  156098,
#  275159,
#  104154,
#  46876,
#  256560,
#  67905,
#  1139,
#  141686,
#  12596,
#  9135,
#  120099,
#  34204,
#  206993,
#  185400,
#  238871,
#  231629,
#  232699,
#  42375,
#  288583,
#  291248,
#  214205,
#  69801,
#  172315,
#  237086,
#  248372,
#  250952,
#  160977,
#  102918,
#  35714,
#  177509,
#  21102,
#  254344,
#  78599,
#  69145,
#  14434,
#  251839,
#  52131,
#  201326,
#  65495,
#  256187,
#  38735,
#  142844,
#  206527,
#  202088,
#  30877,
#  8244,
#  130183,
#  198762,
#  34503,
#  227283,
#  218377,
#  110262,
#  18681,
#  138493,
#  64167,
#  22820,
#  238637,
#  280510,
#  81561,
#  154323,
#  246110,
#  115430,
#  59870,
#  258228,
#  57481,
#  289146,
#  193705,
#  216403,
#  33786,
#  93820,
#  158950,
#  129597,
#  64855,
#  9222,
#  52853,
#  155158,
#  110558,
#  174226,
#  160629,
#  97838,
#  276970,
#  144465,
#  237953,
#  273540,
#  65494,
#  237561,
#  278533,
#  36514,
#  192445,
#  5114,
#  206449,
#  172949,
#  153923,
#  82066,
#  106788,
#  234917,
#  232322,
#  7858,
#  140281,
#  68473,
#  110918,
#  262523,
#  146264,
#  63340,
#  275356,
#  224601,
#  266176,
#  266936,
#  236876,
#  248056,
#  258428,
#  155798,
#  196987,
#  241475,
#  198197,
#  153172,
#  52198,
#  233815,
#  175557,
#  59101,
#  56695,
#  134398,
#  96084,
#  79655,
#  87277,
#  137432,
#  126448,
#  165136,
#  409,
#  274169,
#  34583,
#  267994,
#  282197,
#  120246,
#  197591,
#  65494,
#  279986,
#  1779,
#  39137,
#  237564,
#  179571,
#  196286,
#  26875,
#  119451,
#  227397,
#  243829,
#  252312,
#  214595,
#  247413,
#  163568,
#  133542,
#  281136,
#  10177,
#  50554,
#  238616,
#  174122,
#  243032,
#  131043,
#  8669,
#  131703,
#  125825,
#  248957,
#  10794,
#  218715,
#  104207,
#  39252,
#  271459,
#  191512,
#  124239,
#  219295,
#  110406,
#  286617,
#  151553,
#  291135,
#  226251,
#  233170,
#  128068,
#  101141,
#  272622,
#  29894,
#  36641,
#  63433,
#  30193,
#  52063,
#  28167,
#  277867,
#  175274,
#  260816,
#  269977,
#  276467,
#  210679,
#  38502,
#  289311,
#  142078,
#  112017,
#  179993,
#  51632,
#  98279,
#  142715,
#  127917,
#  73524,
#  164949,
#  193711,
#  207829,
#  10062,
#  30624,
#  38933,
#  76639,
#  126581,
#  106736,
#  147920,
#  66989,
#  56551,
#  292483,
#  232515,
#  93839,
#  216153,
#  14869,
#  49158,
#  172871,
#  134106,
#  284406,
#  138809,
#  32503,
#  16581,
#  45935,
#  188471,
#  68144,
#  130934,
#  218442,
#  285456,
#  289558,
#  243829,
#  278152,
#  21220,
#  278582,
#  173182,
#  239473,
#  276334,
#  41892,
#  85375,
#  159970,
#  143734,
#  29345,
#  274810,
#  37816,
#  10628,
#  173495,
#  156642,
#  103861,
#  203386,
#  251902,
#  228077,
#  239984,
#  1066,
#  38453,
#  191718,
#  112280,
#  99178,
#  282514,
#  157843,
#  20968,
#  179956,
#  150250,
#  85659,
#  152229,
#  67182,
#  181408,
#  67509,
#  72517,
#  84948,
#  152491,
#  24444,
#  107026,
#  100877,
#  182869,
#  71923,
#  255284,
#  149496,
#  126940,
#  80138,
#  288583,
#  106102,
#  272638,
#  111183,
#  118407,
#  221371,
#  215325,
#  29256,
#  159641,
#  63358,
#  284107,
#  77125,
#  240379,
#  243335,
#  153923,
#  78157,
#  162126,
#  284066,
#  158428,
#  280405,
#  112595,
#  157702,
#  263539,
#  157784,
#  174788,
#  141773,
#  57701,
#  159548,
#  70524,
#  180109,
#  115656,
#  10453,
#  150618,
#  62961,
#  285837,
#  129803,
#  141637,
#  208113,
#  105251,
#  189306,
#  190567,
#  66946,
#  293300,
#  201191,
#  151866,
#  214979,
#  283715,
#  210549,
#  159580,
#  2578,
#  158633,
#  229894,
#  250273,
#  178659,
#  120563,
#  201191,
#  47420,
#  8486,
#  187136,
#  216914,
#  131171,
#  51859,
#  273031,
#  168855,
#  89740,
#  255196,
#  59168,
#  164892,
#  232758,
#  16367,
#  144472,
#  138863,
#  40651,
#  159549,
#  72771,
#  33126,
#  23938,
#  213415,
#  78176,
#  170506,
#  177409,
#  255924,
#  187117,
#  193934,
#  20736,
#  210372,
#  225472,
#  14467,
#  46390,
#  56423,
#  255924,
#  152033,
#  183027,
#  160843,
#  257449,
#  14995,
#  4359,
#  134877,
#  113416,
#  249323,
#  270454,
#  133594,
#  201706,
#  94893,
#  70945,
#  275149,
#  286433,
#  146448,
#  177585,
#  128066,
#  214871,
#  238869,
#  211335,
#  279176,
#  26075,
#  206537,
#  274931,
#  173982,
#  191762,
#  111151,
#  293195,
#  231680,
#  103933,
#  227617,
#  211864,
#  171714,
#  204679,
#  131352,
#  57671,
#  5852,
#  31440,
#  216055,
#  90370,
#  113841,
#  82698,
#  244256,
#  226077,
#  235981,
#  54084,
#  46922,
#  118861,
#  193878,
#  152465,
#  282686,
#  58283,
#  249972,
#  49989,
#  33106,
#  170773,
#  40055,
#  121501,
#  226576,
#  75322,
#  153297,
#  293022,
#  255190,
#  232699,
#  288329,
#  118642,
#  94893,
#  137908,
#  87687,
#  281141,
#  106183,
#  96153,
#  74079,
#  141029,
#  216094,
#  213072,
#  213238,
#  135745,
#  13,
#  203607,
#  145146,
#  131564,
#  59296,
#  75833,
#  198544,
#  121002,
#  295485,
#  145607,
#  219744,
#  274874,
#  141772,
#  291044,
#  56317,
#  205730,
#  69847,
#  185363,
#  225926,
#  216514,
#  129085,
#  156250,
#  ...]

# %%
output = []
for i in range(120000):
    output.append([user[i],track[i],prob[i]])

# %%
output
# Out:
# [[199810, 208019, DenseVector([0.9341, 0.0659])],
#  [199810, 74139, DenseVector([0.9341, 0.0659])],
#  [199810, 9903, DenseVector([0.9341, 0.0659])],
#  [199810, 242681, DenseVector([0.9341, 0.0659])],
#  [199810, 18515, DenseVector([0.9341, 0.0659])],
#  [199810, 105760, DenseVector([0.9341, 0.0659])],
#  [199812, 276940, DenseVector([0.9341, 0.0659])],
#  [199812, 142408, DenseVector([0.9341, 0.0659])],
#  [199812, 130023, DenseVector([0.9341, 0.0659])],
#  [199812, 29189, DenseVector([0.9341, 0.0659])],
#  [199812, 223706, DenseVector([0.9341, 0.0659])],
#  [199812, 211361, DenseVector([0.9341, 0.0659])],
#  [199813, 188441, DenseVector([0.9341, 0.0659])],
#  [199813, 20968, DenseVector([0.9341, 0.0659])],
#  [199813, 21571, DenseVector([0.9341, 0.0659])],
#  [199813, 79640, DenseVector([0.9341, 0.0659])],
#  [199813, 184173, DenseVector([0.9341, 0.0659])],
#  [199813, 111874, DenseVector([0.9341, 0.0659])],
#  [199814, 122375, DenseVector([0.9341, 0.0659])],
#  [199814, 189043, DenseVector([0.9341, 0.0659])],
#  [199814, 122429, DenseVector([0.9341, 0.0659])],
#  [199814, 52519, DenseVector([0.9341, 0.0659])],
#  [199814, 232332, DenseVector([0.9341, 0.0659])],
#  [199814, 262193, DenseVector([0.9341, 0.0659])],
#  [199815, 64345, DenseVector([0.9341, 0.0659])],
#  [199815, 118841, DenseVector([0.9341, 0.0659])],
#  [199815, 275682, DenseVector([0.9341, 0.0659])],
#  [199815, 30062, DenseVector([0.9341, 0.0659])],
#  [199815, 258473, DenseVector([0.9341, 0.0659])],
#  [199815, 129866, DenseVector([0.9341, 0.0659])],
#  [199816, 274758, DenseVector([0.9341, 0.0659])],
#  [199816, 102153, DenseVector([0.9341, 0.0659])],
#  [199816, 183464, DenseVector([0.9341, 0.0659])],
#  [199816, 23616, DenseVector([0.9341, 0.0659])],
#  [199816, 81699, DenseVector([0.9341, 0.0659])],
#  [199816, 46627, DenseVector([0.9341, 0.0659])],
#  [199817, 83722, DenseVector([0.9341, 0.0659])],
#  [199817, 200166, DenseVector([0.9341, 0.0659])],
#  [199817, 148603, DenseVector([0.9341, 0.0659])],
#  [199817, 88745, DenseVector([0.9341, 0.0659])],
#  [199817, 144775, DenseVector([0.9341, 0.0659])],
#  [199817, 222966, DenseVector([0.9341, 0.0659])],
#  [199818, 141875, DenseVector([0.9341, 0.0659])],
#  [199818, 290905, DenseVector([0.9341, 0.0659])],
#  [199818, 59789, DenseVector([0.9341, 0.0659])],
#  [199818, 283698, DenseVector([0.9341, 0.0659])],
#  [199818, 106788, DenseVector([0.9341, 0.0659])],
#  [199818, 235999, DenseVector([0.9341, 0.0659])],
#  [199819, 202308, DenseVector([0.9341, 0.0659])],
#  [199819, 36793, DenseVector([0.9341, 0.0659])],
#  [199819, 247549, DenseVector([0.9341, 0.0659])],
#  [199819, 214280, DenseVector([0.9341, 0.0659])],
#  [199819, 123424, DenseVector([0.9341, 0.0659])],
#  [199819, 193003, DenseVector([0.9341, 0.0659])],
#  [199820, 235240, DenseVector([0.9341, 0.0659])],
#  [199820, 292341, DenseVector([0.9341, 0.0659])],
#  [199820, 126082, DenseVector([0.9341, 0.0659])],
#  [199820, 142163, DenseVector([0.9341, 0.0659])],
#  [199820, 20067, DenseVector([0.9341, 0.0659])],
#  [199820, 286335, DenseVector([0.9341, 0.0659])],
#  [199821, 231569, DenseVector([0.9341, 0.0659])],
#  [199821, 51933, DenseVector([0.9341, 0.0659])],
#  [199821, 16949, DenseVector([0.9341, 0.0659])],
#  [199821, 34642, DenseVector([0.9341, 0.0659])],
#  [199821, 229894, DenseVector([0.9341, 0.0659])],
#  [199821, 42811, DenseVector([0.9341, 0.0659])],
#  [199822, 47402, DenseVector([0.9341, 0.0659])],
#  [199822, 21317, DenseVector([0.9341, 0.0659])],
#  [199822, 185734, DenseVector([0.9341, 0.0659])],
#  [199822, 92685, DenseVector([0.9341, 0.0659])],
#  [199822, 110099, DenseVector([0.9341, 0.0659])],
#  [199822, 33495, DenseVector([0.9341, 0.0659])],
#  [199823, 21593, DenseVector([0.9341, 0.0659])],
#  [199823, 132124, DenseVector([0.9341, 0.0659])],
#  [199823, 170625, DenseVector([0.9341, 0.0659])],
#  [199823, 30365, DenseVector([0.9341, 0.0659])],
#  [199823, 143570, DenseVector([0.9341, 0.0659])],
#  [199823, 254625, DenseVector([0.9341, 0.0659])],
#  [199824, 281826, DenseVector([0.9341, 0.0659])],
#  [199824, 253265, DenseVector([0.9341, 0.0659])],
#  [199824, 48891, DenseVector([0.9341, 0.0659])],
#  [199824, 33980, DenseVector([0.9341, 0.0659])],
#  [199824, 207963, DenseVector([0.9341, 0.0659])],
#  [199824, 126528, DenseVector([0.9341, 0.0659])],
#  [199826, 48808, DenseVector([0.9341, 0.0659])],
#  [199826, 223958, DenseVector([0.9341, 0.0659])],
#  [199826, 179298, DenseVector([0.9341, 0.0659])],
#  [199826, 5121, DenseVector([0.9341, 0.0659])],
#  [199826, 31975, DenseVector([0.9341, 0.0659])],
#  [199826, 38775, DenseVector([0.9341, 0.0659])],
#  [199827, 92599, DenseVector([0.9341, 0.0659])],
#  [199827, 75369, DenseVector([0.9341, 0.0659])],
#  [199827, 184197, DenseVector([0.9341, 0.0659])],
#  [199827, 183841, DenseVector([0.9341, 0.0659])],
#  [199827, 197936, DenseVector([0.9341, 0.0659])],
#  [199827, 138391, DenseVector([0.9341, 0.0659])],
#  [199830, 36027, DenseVector([0.9341, 0.0659])],
#  [199830, 29249, DenseVector([0.9341, 0.0659])],
#  [199830, 221237, DenseVector([0.9341, 0.0659])],
#  [199830, 123579, DenseVector([0.9341, 0.0659])],
#  [199830, 19694, DenseVector([0.9341, 0.0659])],
#  [199830, 255036, DenseVector([0.9341, 0.0659])],
#  [199838, 6143, DenseVector([0.9341, 0.0659])],
#  [199838, 24607, DenseVector([0.9341, 0.0659])],
#  [199838, 95726, DenseVector([0.9341, 0.0659])],
#  [199838, 46697, DenseVector([0.9341, 0.0659])],
#  [199838, 256209, DenseVector([0.9341, 0.0659])],
#  [199838, 266780, DenseVector([0.9341, 0.0659])],
#  [199839, 7477, DenseVector([0.9341, 0.0659])],
#  [199839, 266143, DenseVector([0.9341, 0.0659])],
#  [199839, 291820, DenseVector([0.9341, 0.0659])],
#  [199839, 196470, DenseVector([0.9341, 0.0659])],
#  [199839, 263222, DenseVector([0.9341, 0.0659])],
#  [199839, 225097, DenseVector([0.9341, 0.0659])],
#  [199844, 77700, DenseVector([0.9341, 0.0659])],
#  [199844, 138272, DenseVector([0.9341, 0.0659])],
#  [199844, 140229, DenseVector([0.9341, 0.0659])],
#  [199844, 43472, DenseVector([0.9341, 0.0659])],
#  [199844, 118108, DenseVector([0.9341, 0.0659])],
#  [199844, 81165, DenseVector([0.9341, 0.0659])],
#  [199845, 189985, DenseVector([0.9341, 0.0659])],
#  [199845, 31440, DenseVector([0.9341, 0.0659])],
#  [199845, 169945, DenseVector([0.9341, 0.0659])],
#  [199845, 95594, DenseVector([0.9341, 0.0659])],
#  [199845, 238400, DenseVector([0.9341, 0.0659])],
#  [199845, 100669, DenseVector([0.9341, 0.0659])],
#  [199846, 273378, DenseVector([0.9341, 0.0659])],
#  [199846, 19705, DenseVector([0.9341, 0.0659])],
#  [199846, 20499, DenseVector([0.9341, 0.0659])],
#  [199846, 101984, DenseVector([0.9341, 0.0659])],
#  [199846, 214726, DenseVector([0.9341, 0.0659])],
#  [199846, 61792, DenseVector([0.9341, 0.0659])],
#  [199847, 44444, DenseVector([0.9341, 0.0659])],
#  [199847, 39446, DenseVector([0.9341, 0.0659])],
#  [199847, 282901, DenseVector([0.9341, 0.0659])],
#  [199847, 63072, DenseVector([0.9341, 0.0659])],
#  [199847, 19595, DenseVector([0.9341, 0.0659])],
#  [199847, 127769, DenseVector([0.9341, 0.0659])],
#  [199853, 54037, DenseVector([0.9341, 0.0659])],
#  [199853, 89981, DenseVector([0.9341, 0.0659])],
#  [199853, 256134, DenseVector([0.9341, 0.0659])],
#  [199853, 213546, DenseVector([0.9341, 0.0659])],
#  [199853, 222196, DenseVector([0.9341, 0.0659])],
#  [199853, 161111, DenseVector([0.9341, 0.0659])],
#  [199854, 226277, DenseVector([0.9341, 0.0659])],
#  [199854, 92910, DenseVector([0.9341, 0.0659])],
#  [199854, 214592, DenseVector([0.9341, 0.0659])],
#  [199854, 20999, DenseVector([0.9341, 0.0659])],
#  [199854, 154755, DenseVector([0.9341, 0.0659])],
#  [199854, 228397, DenseVector([0.9341, 0.0659])],
#  [199855, 252693, DenseVector([0.9341, 0.0659])],
#  [199855, 69487, DenseVector([0.9341, 0.0659])],
#  [199855, 24631, DenseVector([0.9341, 0.0659])],
#  [199855, 50032, DenseVector([0.9341, 0.0659])],
#  [199855, 277150, DenseVector([0.9341, 0.0659])],
#  [199855, 4836, DenseVector([0.9341, 0.0659])],
#  [199858, 142462, DenseVector([0.9341, 0.0659])],
#  [199858, 255065, DenseVector([0.9341, 0.0659])],
#  [199858, 85596, DenseVector([0.9341, 0.0659])],
#  [199858, 269486, DenseVector([0.9341, 0.0659])],
#  [199858, 30595, DenseVector([0.9341, 0.0659])],
#  [199858, 37731, DenseVector([0.9341, 0.0659])],
#  [199859, 22400, DenseVector([0.9341, 0.0659])],
#  [199859, 105128, DenseVector([0.9341, 0.0659])],
#  [199859, 2877, DenseVector([0.9341, 0.0659])],
#  [199859, 51667, DenseVector([0.9341, 0.0659])],
#  [199859, 289911, DenseVector([0.9341, 0.0659])],
#  [199859, 17, DenseVector([0.9341, 0.0659])],
#  [199861, 192584, DenseVector([0.9341, 0.0659])],
#  [199861, 56525, DenseVector([0.9341, 0.0659])],
#  [199861, 94381, DenseVector([0.9341, 0.0659])],
#  [199861, 249701, DenseVector([0.9341, 0.0659])],
#  [199861, 127111, DenseVector([0.9341, 0.0659])],
#  [199861, 77154, DenseVector([0.9341, 0.0659])],
#  [199862, 80123, DenseVector([0.9341, 0.0659])],
#  [199862, 108161, DenseVector([0.9341, 0.0659])],
#  [199862, 179298, DenseVector([0.9341, 0.0659])],
#  [199862, 280411, DenseVector([0.9341, 0.0659])],
#  [199862, 196729, DenseVector([0.9341, 0.0659])],
#  [199862, 225847, DenseVector([0.9341, 0.0659])],
#  [199863, 222604, DenseVector([0.9341, 0.0659])],
#  [199863, 126413, DenseVector([0.9341, 0.0659])],
#  [199863, 144718, DenseVector([0.9341, 0.0659])],
#  [199863, 241999, DenseVector([0.9341, 0.0659])],
#  [199863, 184020, DenseVector([0.9341, 0.0659])],
#  [199863, 249930, DenseVector([0.9341, 0.0659])],
#  [199866, 142729, DenseVector([0.9341, 0.0659])],
#  [199866, 117929, DenseVector([0.9341, 0.0659])],
#  [199866, 252600, DenseVector([0.9341, 0.0659])],
#  [199866, 125126, DenseVector([0.9341, 0.0659])],
#  [199866, 46889, DenseVector([0.9341, 0.0659])],
#  [199866, 291314, DenseVector([0.9341, 0.0659])],
#  [199868, 24085, DenseVector([0.9341, 0.0659])],
#  [199868, 80589, DenseVector([0.9341, 0.0659])],
#  [199868, 79604, DenseVector([0.9341, 0.0659])],
#  [199868, 218286, DenseVector([0.9341, 0.0659])],
#  [199868, 122067, DenseVector([0.9341, 0.0659])],
#  [199868, 257899, DenseVector([0.9341, 0.0659])],
#  [199873, 8379, DenseVector([0.9341, 0.0659])],
#  [199873, 217580, DenseVector([0.9341, 0.0659])],
#  [199873, 65230, DenseVector([0.9341, 0.0659])],
#  [199873, 65855, DenseVector([0.9341, 0.0659])],
#  [199873, 241597, DenseVector([0.9341, 0.0659])],
#  [199873, 187050, DenseVector([0.9341, 0.0659])],
#  [199876, 257097, DenseVector([0.9341, 0.0659])],
#  [199876, 277360, DenseVector([0.9341, 0.0659])],
#  [199876, 69317, DenseVector([0.9341, 0.0659])],
#  [199876, 47894, DenseVector([0.9341, 0.0659])],
#  [199876, 102449, DenseVector([0.9341, 0.0659])],
#  [199876, 267088, DenseVector([0.9341, 0.0659])],
#  [199880, 266143, DenseVector([0.9341, 0.0659])],
#  [199880, 224615, DenseVector([0.9341, 0.0659])],
#  [199880, 154327, DenseVector([0.9341, 0.0659])],
#  [199880, 14107, DenseVector([0.9341, 0.0659])],
#  [199880, 22640, DenseVector([0.9341, 0.0659])],
#  [199880, 133341, DenseVector([0.9341, 0.0659])],
#  [199882, 146575, DenseVector([0.9341, 0.0659])],
#  [199882, 192238, DenseVector([0.9341, 0.0659])],
#  [199882, 109824, DenseVector([0.9341, 0.0659])],
#  [199882, 125958, DenseVector([0.9341, 0.0659])],
#  [199882, 79309, DenseVector([0.9341, 0.0659])],
#  [199882, 42782, DenseVector([0.9341, 0.0659])],
#  [199884, 36155, DenseVector([0.9341, 0.0659])],
#  [199884, 5444, DenseVector([0.9341, 0.0659])],
#  [199884, 150640, DenseVector([0.9341, 0.0659])],
#  [199884, 155463, DenseVector([0.9341, 0.0659])],
#  [199884, 247800, DenseVector([0.9341, 0.0659])],
#  [199884, 152366, DenseVector([0.9341, 0.0659])],
#  [199886, 134307, DenseVector([0.9341, 0.0659])],
#  [199886, 255399, DenseVector([0.9341, 0.0659])],
#  [199886, 155743, DenseVector([0.9341, 0.0659])],
#  [199886, 151269, DenseVector([0.9341, 0.0659])],
#  [199886, 200432, DenseVector([0.9341, 0.0659])],
#  [199886, 87913, DenseVector([0.9341, 0.0659])],
#  [199890, 114634, DenseVector([0.9341, 0.0659])],
#  [199890, 151926, DenseVector([0.9341, 0.0659])],
#  [199890, 190001, DenseVector([0.9341, 0.0659])],
#  [199890, 286440, DenseVector([0.9341, 0.0659])],
#  [199890, 48289, DenseVector([0.9341, 0.0659])],
#  [199890, 141713, DenseVector([0.9341, 0.0659])],
#  [199891, 32135, DenseVector([0.9341, 0.0659])],
#  [199891, 244657, DenseVector([0.9341, 0.0659])],
#  [199891, 117789, DenseVector([0.9341, 0.0659])],
#  [199891, 45103, DenseVector([0.9341, 0.0659])],
#  [199891, 279606, DenseVector([0.9341, 0.0659])],
#  [199891, 280110, DenseVector([0.9341, 0.0659])],
#  [199894, 279067, DenseVector([0.9341, 0.0659])],
#  [199894, 15811, DenseVector([0.9341, 0.0659])],
#  [199894, 250006, DenseVector([0.9341, 0.0659])],
#  [199894, 31746, DenseVector([0.9341, 0.0659])],
#  [199894, 251949, DenseVector([0.9341, 0.0659])],
#  [199894, 9592, DenseVector([0.9341, 0.0659])],
#  [199895, 195551, DenseVector([0.9341, 0.0659])],
#  [199895, 69797, DenseVector([0.9341, 0.0659])],
#  [199895, 59891, DenseVector([0.9341, 0.0659])],
#  [199895, 249919, DenseVector([0.9341, 0.0659])],
#  [199895, 229468, DenseVector([0.9341, 0.0659])],
#  [199895, 276415, DenseVector([0.9341, 0.0659])],
#  [199896, 175151, DenseVector([0.9341, 0.0659])],
#  [199896, 101756, DenseVector([0.9341, 0.0659])],
#  [199896, 222456, DenseVector([0.9341, 0.0659])],
#  [199896, 183890, DenseVector([0.9341, 0.0659])],
#  [199896, 42748, DenseVector([0.9341, 0.0659])],
#  [199896, 59296, DenseVector([0.9341, 0.0659])],
#  [199899, 30902, DenseVector([0.9341, 0.0659])],
#  [199899, 54300, DenseVector([0.9341, 0.0659])],
#  [199899, 46394, DenseVector([0.9341, 0.0659])],
#  [199899, 236744, DenseVector([0.9341, 0.0659])],
#  [199899, 40880, DenseVector([0.9341, 0.0659])],
#  [199899, 210352, DenseVector([0.9341, 0.0659])],
#  [199900, 219739, DenseVector([0.9341, 0.0659])],
#  [199900, 287949, DenseVector([0.9341, 0.0659])],
#  [199900, 23822, DenseVector([0.9341, 0.0659])],
#  [199900, 44210, DenseVector([0.9341, 0.0659])],
#  [199900, 261886, DenseVector([0.9341, 0.0659])],
#  [199900, 110099, DenseVector([0.9341, 0.0659])],
#  [199902, 111243, DenseVector([0.9341, 0.0659])],
#  [199902, 124466, DenseVector([0.9341, 0.0659])],
#  [199902, 263958, DenseVector([0.9341, 0.0659])],
#  [199902, 249140, DenseVector([0.9341, 0.0659])],
#  [199902, 298, DenseVector([0.9341, 0.0659])],
#  [199902, 127445, DenseVector([0.9341, 0.0659])],
#  [199907, 64481, DenseVector([0.9341, 0.0659])],
#  [199907, 61826, DenseVector([0.9341, 0.0659])],
#  [199907, 54636, DenseVector([0.9341, 0.0659])],
#  [199907, 52391, DenseVector([0.9341, 0.0659])],
#  [199907, 172050, DenseVector([0.9341, 0.0659])],
#  [199907, 78355, DenseVector([0.9341, 0.0659])],
#  [199911, 152843, DenseVector([0.9341, 0.0659])],
#  [199911, 23252, DenseVector([0.9341, 0.0659])],
#  [199911, 170920, DenseVector([0.9341, 0.0659])],
#  [199911, 21878, DenseVector([0.9341, 0.0659])],
#  [199911, 50179, DenseVector([0.9341, 0.0659])],
#  [199911, 229538, DenseVector([0.9341, 0.0659])],
#  [199912, 252021, DenseVector([0.9341, 0.0659])],
#  [199912, 125831, DenseVector([0.9341, 0.0659])],
#  [199912, 233293, DenseVector([0.9341, 0.0659])],
#  [199912, 286721, DenseVector([0.9341, 0.0659])],
#  [199912, 87357, DenseVector([0.9341, 0.0659])],
#  [199912, 188926, DenseVector([0.9341, 0.0659])],
#  [199914, 284745, DenseVector([0.9341, 0.0659])],
#  [199914, 137479, DenseVector([0.9341, 0.0659])],
#  [199914, 94531, DenseVector([0.9341, 0.0659])],
#  [199914, 295555, DenseVector([0.9341, 0.0659])],
#  [199914, 262472, DenseVector([0.9341, 0.0659])],
#  [199914, 78278, DenseVector([0.9341, 0.0659])],
#  [199915, 118642, DenseVector([0.9341, 0.0659])],
#  [199915, 252839, DenseVector([0.9341, 0.0659])],
#  [199915, 232361, DenseVector([0.9341, 0.0659])],
#  [199915, 11535, DenseVector([0.9341, 0.0659])],
#  [199915, 266171, DenseVector([0.9341, 0.0659])],
#  [199915, 29554, DenseVector([0.9341, 0.0659])],
#  [199918, 251164, DenseVector([0.9341, 0.0659])],
#  [199918, 114265, DenseVector([0.9341, 0.0659])],
#  [199918, 103426, DenseVector([0.9341, 0.0659])],
#  [199918, 138333, DenseVector([0.9341, 0.0659])],
#  [199918, 150958, DenseVector([0.9341, 0.0659])],
#  [199918, 242417, DenseVector([0.9341, 0.0659])],
#  [199920, 237580, DenseVector([0.9341, 0.0659])],
#  [199920, 138590, DenseVector([0.9341, 0.0659])],
#  [199920, 77933, DenseVector([0.9341, 0.0659])],
#  [199920, 247578, DenseVector([0.9341, 0.0659])],
#  [199920, 144100, DenseVector([0.9341, 0.0659])],
#  [199920, 106344, DenseVector([0.9341, 0.0659])],
#  [199921, 48891, DenseVector([0.9341, 0.0659])],
#  [199921, 175928, DenseVector([0.9341, 0.0659])],
#  [199921, 143902, DenseVector([0.9341, 0.0659])],
#  [199921, 95242, DenseVector([0.9341, 0.0659])],
#  [199921, 198864, DenseVector([0.9341, 0.0659])],
#  [199921, 76816, DenseVector([0.9341, 0.0659])],
#  [199924, 108161, DenseVector([0.9341, 0.0659])],
#  [199924, 16078, DenseVector([0.9341, 0.0659])],
#  [199924, 120535, DenseVector([0.9341, 0.0659])],
#  [199924, 54651, DenseVector([0.9341, 0.0659])],
#  [199924, 49904, DenseVector([0.9341, 0.0659])],
#  [199924, 62568, DenseVector([0.9341, 0.0659])],
#  [199926, 142473, DenseVector([0.9341, 0.0659])],
#  [199926, 180224, DenseVector([0.9341, 0.0659])],
#  [199926, 73940, DenseVector([0.9341, 0.0659])],
#  [199926, 44783, DenseVector([0.9341, 0.0659])],
#  [199926, 139444, DenseVector([0.9341, 0.0659])],
#  [199926, 41368, DenseVector([0.9341, 0.0659])],
#  [199928, 137693, DenseVector([0.9341, 0.0659])],
#  [199928, 87125, DenseVector([0.9341, 0.0659])],
#  [199928, 171481, DenseVector([0.9341, 0.0659])],
#  [199928, 251278, DenseVector([0.9341, 0.0659])],
#  [199928, 65142, DenseVector([0.9341, 0.0659])],
#  [199928, 215837, DenseVector([0.9341, 0.0659])],
#  [199931, 140334, DenseVector([0.9341, 0.0659])],
#  [199931, 90442, DenseVector([0.9341, 0.0659])],
#  [199931, 161183, DenseVector([0.9341, 0.0659])],
#  [199931, 242657, DenseVector([0.9341, 0.0659])],
#  [199931, 149874, DenseVector([0.9341, 0.0659])],
#  [199931, 122518, DenseVector([0.9341, 0.0659])],
#  [199932, 131954, DenseVector([0.9341, 0.0659])],
#  [199932, 68360, DenseVector([0.9341, 0.0659])],
#  [199932, 119027, DenseVector([0.9341, 0.0659])],
#  [199932, 284320, DenseVector([0.9341, 0.0659])],
#  [199932, 104542, DenseVector([0.9341, 0.0659])],
#  [199932, 2924, DenseVector([0.9341, 0.0659])],
#  [199934, 222840, DenseVector([0.9341, 0.0659])],
#  [199934, 18198, DenseVector([0.9341, 0.0659])],
#  [199934, 37960, DenseVector([0.9341, 0.0659])],
#  [199934, 250816, DenseVector([0.9341, 0.0659])],
#  [199934, 170214, DenseVector([0.9341, 0.0659])],
#  [199934, 44222, DenseVector([0.9341, 0.0659])],
#  [199936, 32596, DenseVector([0.9341, 0.0659])],
#  [199936, 12969, DenseVector([0.9341, 0.0659])],
#  [199936, 216902, DenseVector([0.9341, 0.0659])],
#  [199936, 89110, DenseVector([0.9341, 0.0659])],
#  [199936, 71574, DenseVector([0.9341, 0.0659])],
#  [199936, 245276, DenseVector([0.9341, 0.0659])],
#  [199937, 20538, DenseVector([0.9341, 0.0659])],
#  [199937, 151964, DenseVector([0.9341, 0.0659])],
#  [199937, 171735, DenseVector([0.9341, 0.0659])],
#  [199937, 163166, DenseVector([0.9341, 0.0659])],
#  [199937, 95326, DenseVector([0.9341, 0.0659])],
#  [199937, 270004, DenseVector([0.9341, 0.0659])],
#  [199939, 111062, DenseVector([0.9341, 0.0659])],
#  [199939, 223859, DenseVector([0.9341, 0.0659])],
#  [199939, 165847, DenseVector([0.9341, 0.0659])],
#  [199939, 245574, DenseVector([0.9341, 0.0659])],
#  [199939, 171700, DenseVector([0.9341, 0.0659])],
#  [199939, 12922, DenseVector([0.9341, 0.0659])],
#  [199941, 135759, DenseVector([0.9341, 0.0659])],
#  [199941, 261128, DenseVector([0.9341, 0.0659])],
#  [199941, 220067, DenseVector([0.9341, 0.0659])],
#  [199941, 191060, DenseVector([0.9341, 0.0659])],
#  [199941, 45668, DenseVector([0.9341, 0.0659])],
#  [199941, 92843, DenseVector([0.9341, 0.0659])],
#  [199944, 67182, DenseVector([0.9341, 0.0659])],
#  [199944, 281157, DenseVector([0.9341, 0.0659])],
#  [199944, 18733, DenseVector([0.9341, 0.0659])],
#  [199944, 166911, DenseVector([0.9341, 0.0659])],
#  [199944, 181496, DenseVector([0.9341, 0.0659])],
#  [199944, 118642, DenseVector([0.9341, 0.0659])],
#  [199947, 107099, DenseVector([0.9341, 0.0659])],
#  [199947, 99698, DenseVector([0.9341, 0.0659])],
#  [199947, 196040, DenseVector([0.9341, 0.0659])],
#  [199947, 52853, DenseVector([0.9341, 0.0659])],
#  [199947, 19388, DenseVector([0.9341, 0.0659])],
#  [199947, 163568, DenseVector([0.9341, 0.0659])],
#  [199949, 157403, DenseVector([0.9341, 0.0659])],
#  [199949, 262177, DenseVector([0.9341, 0.0659])],
#  [199949, 187117, DenseVector([0.9341, 0.0659])],
#  [199949, 73710, DenseVector([0.9341, 0.0659])],
#  [199949, 157478, DenseVector([0.9341, 0.0659])],
#  [199949, 48583, DenseVector([0.9341, 0.0659])],
#  [199954, 44782, DenseVector([0.9341, 0.0659])],
#  [199954, 75676, DenseVector([0.9341, 0.0659])],
#  [199954, 144640, DenseVector([0.9341, 0.0659])],
#  [199954, 277674, DenseVector([0.9341, 0.0659])],
#  [199954, 85063, DenseVector([0.9341, 0.0659])],
#  [199954, 92599, DenseVector([0.9341, 0.0659])],
#  [199955, 264558, DenseVector([0.9341, 0.0659])],
#  [199955, 224104, DenseVector([0.9341, 0.0659])],
#  [199955, 267631, DenseVector([0.9341, 0.0659])],
#  [199955, 152820, DenseVector([0.9341, 0.0659])],
#  [199955, 99223, DenseVector([0.9341, 0.0659])],
#  [199955, 111277, DenseVector([0.9341, 0.0659])],
#  [199958, 248267, DenseVector([0.9341, 0.0659])],
#  [199958, 202112, DenseVector([0.9341, 0.0659])],
#  [199958, 7740, DenseVector([0.9341, 0.0659])],
#  [199958, 263828, DenseVector([0.9341, 0.0659])],
#  [199958, 37057, DenseVector([0.9341, 0.0659])],
#  [199958, 43391, DenseVector([0.9341, 0.0659])],
#  [199961, 72011, DenseVector([0.9341, 0.0659])],
#  [199961, 85844, DenseVector([0.9341, 0.0659])],
#  [199961, 17790, DenseVector([0.9341, 0.0659])],
#  [199961, 12010, DenseVector([0.9341, 0.0659])],
#  [199961, 203948, DenseVector([0.9341, 0.0659])],
#  [199961, 44094, DenseVector([0.9341, 0.0659])],
#  [199962, 14689, DenseVector([0.9341, 0.0659])],
#  [199962, 39799, DenseVector([0.9341, 0.0659])],
#  [199962, 39602, DenseVector([0.9341, 0.0659])],
#  [199962, 38287, DenseVector([0.9341, 0.0659])],
#  [199962, 63433, DenseVector([0.9341, 0.0659])],
#  [199962, 250006, DenseVector([0.9341, 0.0659])],
#  [199963, 202739, DenseVector([0.9341, 0.0659])],
#  [199963, 214979, DenseVector([0.9341, 0.0659])],
#  [199963, 2843, DenseVector([0.9341, 0.0659])],
#  [199963, 132003, DenseVector([0.9341, 0.0659])],
#  [199963, 183159, DenseVector([0.9341, 0.0659])],
#  [199963, 222425, DenseVector([0.9341, 0.0659])],
#  [199966, 94498, DenseVector([0.9341, 0.0659])],
#  [199966, 85844, DenseVector([0.9341, 0.0659])],
#  [199966, 17907, DenseVector([0.9341, 0.0659])],
#  [199966, 6173, DenseVector([0.9341, 0.0659])],
#  [199966, 156103, DenseVector([0.9341, 0.0659])],
#  [199966, 4310, DenseVector([0.9341, 0.0659])],
#  [199973, 9810, DenseVector([0.9341, 0.0659])],
#  [199973, 143588, DenseVector([0.9341, 0.0659])],
#  [199973, 257449, DenseVector([0.9341, 0.0659])],
#  [199973, 39447, DenseVector([0.9341, 0.0659])],
#  [199973, 204267, DenseVector([0.9341, 0.0659])],
#  [199973, 172907, DenseVector([0.9341, 0.0659])],
#  [199974, 295907, DenseVector([0.9341, 0.0659])],
#  [199974, 10628, DenseVector([0.9341, 0.0659])],
#  [199974, 286329, DenseVector([0.9341, 0.0659])],
#  [199974, 73886, DenseVector([0.9341, 0.0659])],
#  [199974, 70203, DenseVector([0.9341, 0.0659])],
#  [199974, 282197, DenseVector([0.9341, 0.0659])],
#  [199976, 125958, DenseVector([0.9341, 0.0659])],
#  [199976, 138333, DenseVector([0.9341, 0.0659])],
#  [199976, 63855, DenseVector([0.9341, 0.0659])],
#  [199976, 88123, DenseVector([0.9341, 0.0659])],
#  [199976, 188301, DenseVector([0.9341, 0.0659])],
#  [199976, 116957, DenseVector([0.9341, 0.0659])],
#  [199977, 293108, DenseVector([0.9341, 0.0659])],
#  [199977, 211659, DenseVector([0.9341, 0.0659])],
#  [199977, 61827, DenseVector([0.9341, 0.0659])],
#  [199977, 12127, DenseVector([0.9341, 0.0659])],
#  [199977, 153742, DenseVector([0.9341, 0.0659])],
#  [199977, 281844, DenseVector([0.9341, 0.0659])],
#  [199981, 244686, DenseVector([0.9341, 0.0659])],
#  [199981, 190154, DenseVector([0.9341, 0.0659])],
#  [199981, 206026, DenseVector([0.9341, 0.0659])],
#  [199981, 260780, DenseVector([0.9341, 0.0659])],
#  [199981, 142675, DenseVector([0.9341, 0.0659])],
#  [199981, 154382, DenseVector([0.9341, 0.0659])],
#  [199982, 220973, DenseVector([0.9341, 0.0659])],
#  [199982, 79550, DenseVector([0.9341, 0.0659])],
#  [199982, 183431, DenseVector([0.9341, 0.0659])],
#  [199982, 114059, DenseVector([0.9341, 0.0659])],
#  [199982, 120535, DenseVector([0.9341, 0.0659])],
#  [199982, 189306, DenseVector([0.9341, 0.0659])],
#  [199983, 240746, DenseVector([0.9341, 0.0659])],
#  [199983, 163720, DenseVector([0.9341, 0.0659])],
#  [199983, 6330, DenseVector([0.9341, 0.0659])],
#  [199983, 47483, DenseVector([0.9341, 0.0659])],
#  [199983, 4102, DenseVector([0.9341, 0.0659])],
#  [199983, 245818, DenseVector([0.9341, 0.0659])],
#  [199984, 199756, DenseVector([0.9341, 0.0659])],
#  [199984, 66754, DenseVector([0.9341, 0.0659])],
#  [199984, 268182, DenseVector([0.9341, 0.0659])],
#  [199984, 197751, DenseVector([0.9341, 0.0659])],
#  [199984, 135194, DenseVector([0.9341, 0.0659])],
#  [199984, 254703, DenseVector([0.9341, 0.0659])],
#  [199989, 174481, DenseVector([0.9341, 0.0659])],
#  [199989, 133167, DenseVector([0.9341, 0.0659])],
#  [199989, 184197, DenseVector([0.9341, 0.0659])],
#  [199989, 145221, DenseVector([0.9341, 0.0659])],
#  [199989, 70738, DenseVector([0.9341, 0.0659])],
#  [199989, 48244, DenseVector([0.9341, 0.0659])],
#  [199991, 108560, DenseVector([0.9341, 0.0659])],
#  [199991, 152985, DenseVector([0.9341, 0.0659])],
#  [199991, 200612, DenseVector([0.9341, 0.0659])],
#  [199991, 18684, DenseVector([0.9341, 0.0659])],
#  [199991, 32651, DenseVector([0.9341, 0.0659])],
#  [199991, 247852, DenseVector([0.9341, 0.0659])],
#  [199996, 75564, DenseVector([0.9341, 0.0659])],
#  [199996, 154321, DenseVector([0.9341, 0.0659])],
#  [199996, 61539, DenseVector([0.9341, 0.0659])],
#  [199996, 44110, DenseVector([0.9341, 0.0659])],
#  [199996, 237168, DenseVector([0.9341, 0.0659])],
#  [199996, 58813, DenseVector([0.9341, 0.0659])],
#  [199997, 210679, DenseVector([0.9341, 0.0659])],
#  [199997, 5791, DenseVector([0.9341, 0.0659])],
#  [199997, 233951, DenseVector([0.9341, 0.0659])],
#  [199997, 12756, DenseVector([0.9341, 0.0659])],
#  [199997, 37154, DenseVector([0.9341, 0.0659])],
#  [199997, 215013, DenseVector([0.9341, 0.0659])],
#  [200000, 28885, DenseVector([0.9341, 0.0659])],
#  [200000, 245668, DenseVector([0.9341, 0.0659])],
#  [200000, 66741, DenseVector([0.9341, 0.0659])],
#  [200000, 61924, DenseVector([0.9341, 0.0659])],
#  [200000, 156098, DenseVector([0.9341, 0.0659])],
#  [200000, 275159, DenseVector([0.9341, 0.0659])],
#  [200008, 104154, DenseVector([0.9341, 0.0659])],
#  [200008, 46876, DenseVector([0.9341, 0.0659])],
#  [200008, 256560, DenseVector([0.9341, 0.0659])],
#  [200008, 67905, DenseVector([0.9341, 0.0659])],
#  [200008, 1139, DenseVector([0.9341, 0.0659])],
#  [200008, 141686, DenseVector([0.9341, 0.0659])],
#  [200011, 12596, DenseVector([0.9341, 0.0659])],
#  [200011, 9135, DenseVector([0.9341, 0.0659])],
#  [200011, 120099, DenseVector([0.9341, 0.0659])],
#  [200011, 34204, DenseVector([0.9341, 0.0659])],
#  [200011, 206993, DenseVector([0.9341, 0.0659])],
#  [200011, 185400, DenseVector([0.9341, 0.0659])],
#  [200015, 238871, DenseVector([0.9341, 0.0659])],
#  [200015, 231629, DenseVector([0.9341, 0.0659])],
#  [200015, 232699, DenseVector([0.9341, 0.0659])],
#  [200015, 42375, DenseVector([0.9341, 0.0659])],
#  [200015, 288583, DenseVector([0.9341, 0.0659])],
#  [200015, 291248, DenseVector([0.9341, 0.0659])],
#  [200017, 214205, DenseVector([0.9341, 0.0659])],
#  [200017, 69801, DenseVector([0.9341, 0.0659])],
#  [200017, 172315, DenseVector([0.9341, 0.0659])],
#  [200017, 237086, DenseVector([0.9341, 0.0659])],
#  [200017, 248372, DenseVector([0.9341, 0.0659])],
#  [200017, 250952, DenseVector([0.9341, 0.0659])],
#  [200020, 160977, DenseVector([0.9341, 0.0659])],
#  [200020, 102918, DenseVector([0.9341, 0.0659])],
#  [200020, 35714, DenseVector([0.9341, 0.0659])],
#  [200020, 177509, DenseVector([0.9341, 0.0659])],
#  [200020, 21102, DenseVector([0.9341, 0.0659])],
#  [200020, 254344, DenseVector([0.9341, 0.0659])],
#  [200022, 78599, DenseVector([0.9341, 0.0659])],
#  [200022, 69145, DenseVector([0.9341, 0.0659])],
#  [200022, 14434, DenseVector([0.9341, 0.0659])],
#  [200022, 251839, DenseVector([0.9341, 0.0659])],
#  [200022, 52131, DenseVector([0.9341, 0.0659])],
#  [200022, 201326, DenseVector([0.9341, 0.0659])],
#  [200024, 65495, DenseVector([0.9341, 0.0659])],
#  [200024, 256187, DenseVector([0.9341, 0.0659])],
#  [200024, 38735, DenseVector([0.9341, 0.0659])],
#  [200024, 142844, DenseVector([0.9341, 0.0659])],
#  [200024, 206527, DenseVector([0.9341, 0.0659])],
#  [200024, 202088, DenseVector([0.9341, 0.0659])],
#  [200031, 30877, DenseVector([0.9341, 0.0659])],
#  [200031, 8244, DenseVector([0.9341, 0.0659])],
#  [200031, 130183, DenseVector([0.9341, 0.0659])],
#  [200031, 198762, DenseVector([0.9341, 0.0659])],
#  [200031, 34503, DenseVector([0.9341, 0.0659])],
#  [200031, 227283, DenseVector([0.9341, 0.0659])],
#  [200032, 218377, DenseVector([0.9341, 0.0659])],
#  [200032, 110262, DenseVector([0.9341, 0.0659])],
#  [200032, 18681, DenseVector([0.9341, 0.0659])],
#  [200032, 138493, DenseVector([0.9341, 0.0659])],
#  [200032, 64167, DenseVector([0.9341, 0.0659])],
#  [200032, 22820, DenseVector([0.9341, 0.0659])],
#  [200033, 238637, DenseVector([0.9341, 0.0659])],
#  [200033, 280510, DenseVector([0.9341, 0.0659])],
#  [200033, 81561, DenseVector([0.9341, 0.0659])],
#  [200033, 154323, DenseVector([0.9341, 0.0659])],
#  [200033, 246110, DenseVector([0.9341, 0.0659])],
#  [200033, 115430, DenseVector([0.9341, 0.0659])],
#  [200034, 59870, DenseVector([0.9341, 0.0659])],
#  [200034, 258228, DenseVector([0.9341, 0.0659])],
#  [200034, 57481, DenseVector([0.9341, 0.0659])],
#  [200034, 289146, DenseVector([0.9341, 0.0659])],
#  [200034, 193705, DenseVector([0.9341, 0.0659])],
#  [200034, 216403, DenseVector([0.9341, 0.0659])],
#  [200039, 33786, DenseVector([0.9341, 0.0659])],
#  [200039, 93820, DenseVector([0.9341, 0.0659])],
#  [200039, 158950, DenseVector([0.9341, 0.0659])],
#  [200039, 129597, DenseVector([0.9341, 0.0659])],
#  [200039, 64855, DenseVector([0.9341, 0.0659])],
#  [200039, 9222, DenseVector([0.9341, 0.0659])],
#  [200042, 52853, DenseVector([0.9341, 0.0659])],
#  [200042, 155158, DenseVector([0.9341, 0.0659])],
#  [200042, 110558, DenseVector([0.9341, 0.0659])],
#  [200042, 174226, DenseVector([0.9341, 0.0659])],
#  [200042, 160629, DenseVector([0.9341, 0.0659])],
#  [200042, 97838, DenseVector([0.9341, 0.0659])],
#  [200044, 276970, DenseVector([0.9341, 0.0659])],
#  [200044, 144465, DenseVector([0.9341, 0.0659])],
#  [200044, 237953, DenseVector([0.9341, 0.0659])],
#  [200044, 273540, DenseVector([0.9341, 0.0659])],
#  [200044, 65494, DenseVector([0.9341, 0.0659])],
#  [200044, 237561, DenseVector([0.9341, 0.0659])],
#  [200045, 278533, DenseVector([0.9341, 0.0659])],
#  [200045, 36514, DenseVector([0.9341, 0.0659])],
#  [200045, 192445, DenseVector([0.9341, 0.0659])],
#  [200045, 5114, DenseVector([0.9341, 0.0659])],
#  [200045, 206449, DenseVector([0.9341, 0.0659])],
#  [200045, 172949, DenseVector([0.9341, 0.0659])],
#  [200046, 153923, DenseVector([0.9341, 0.0659])],
#  [200046, 82066, DenseVector([0.9341, 0.0659])],
#  [200046, 106788, DenseVector([0.9341, 0.0659])],
#  [200046, 234917, DenseVector([0.9341, 0.0659])],
#  [200046, 232322, DenseVector([0.9341, 0.0659])],
#  [200046, 7858, DenseVector([0.9341, 0.0659])],
#  [200049, 140281, DenseVector([0.9341, 0.0659])],
#  [200049, 68473, DenseVector([0.9341, 0.0659])],
#  [200049, 110918, DenseVector([0.9341, 0.0659])],
#  [200049, 262523, DenseVector([0.9341, 0.0659])],
#  [200049, 146264, DenseVector([0.9341, 0.0659])],
#  [200049, 63340, DenseVector([0.9341, 0.0659])],
#  [200053, 275356, DenseVector([0.9341, 0.0659])],
#  [200053, 224601, DenseVector([0.9341, 0.0659])],
#  [200053, 266176, DenseVector([0.9341, 0.0659])],
#  [200053, 266936, DenseVector([0.9341, 0.0659])],
#  [200053, 236876, DenseVector([0.9341, 0.0659])],
#  [200053, 248056, DenseVector([0.9341, 0.0659])],
#  [200054, 258428, DenseVector([0.9341, 0.0659])],
#  [200054, 155798, DenseVector([0.9341, 0.0659])],
#  [200054, 196987, DenseVector([0.9341, 0.0659])],
#  [200054, 241475, DenseVector([0.9341, 0.0659])],
#  [200054, 198197, DenseVector([0.9341, 0.0659])],
#  [200054, 153172, DenseVector([0.9341, 0.0659])],
#  [200055, 52198, DenseVector([0.9341, 0.0659])],
#  [200055, 233815, DenseVector([0.9341, 0.0659])],
#  [200055, 175557, DenseVector([0.9341, 0.0659])],
#  [200055, 59101, DenseVector([0.9341, 0.0659])],
#  [200055, 56695, DenseVector([0.9341, 0.0659])],
#  [200055, 134398, DenseVector([0.9341, 0.0659])],
#  [200061, 96084, DenseVector([0.9341, 0.0659])],
#  [200061, 79655, DenseVector([0.9341, 0.0659])],
#  [200061, 87277, DenseVector([0.9341, 0.0659])],
#  [200061, 137432, DenseVector([0.9341, 0.0659])],
#  [200061, 126448, DenseVector([0.9341, 0.0659])],
#  [200061, 165136, DenseVector([0.9341, 0.0659])],
#  [200062, 409, DenseVector([0.9341, 0.0659])],
#  [200062, 274169, DenseVector([0.9341, 0.0659])],
#  [200062, 34583, DenseVector([0.9341, 0.0659])],
#  [200062, 267994, DenseVector([0.9341, 0.0659])],
#  [200062, 282197, DenseVector([0.9341, 0.0659])],
#  [200062, 120246, DenseVector([0.9341, 0.0659])],
#  [200063, 197591, DenseVector([0.9341, 0.0659])],
#  [200063, 65494, DenseVector([0.9341, 0.0659])],
#  [200063, 279986, DenseVector([0.9341, 0.0659])],
#  [200063, 1779, DenseVector([0.9341, 0.0659])],
#  [200063, 39137, DenseVector([0.9341, 0.0659])],
#  [200063, 237564, DenseVector([0.9341, 0.0659])],
#  [200065, 179571, DenseVector([0.9341, 0.0659])],
#  [200065, 196286, DenseVector([0.9341, 0.0659])],
#  [200065, 26875, DenseVector([0.9341, 0.0659])],
#  [200065, 119451, DenseVector([0.9341, 0.0659])],
#  [200065, 227397, DenseVector([0.9341, 0.0659])],
#  [200065, 243829, DenseVector([0.9341, 0.0659])],
#  [200066, 252312, DenseVector([0.9341, 0.0659])],
#  [200066, 214595, DenseVector([0.9341, 0.0659])],
#  [200066, 247413, DenseVector([0.9341, 0.0659])],
#  [200066, 163568, DenseVector([0.9341, 0.0659])],
#  [200066, 133542, DenseVector([0.9341, 0.0659])],
#  [200066, 281136, DenseVector([0.9341, 0.0659])],
#  [200067, 10177, DenseVector([0.9341, 0.0659])],
#  [200067, 50554, DenseVector([0.9341, 0.0659])],
#  [200067, 238616, DenseVector([0.9341, 0.0659])],
#  [200067, 174122, DenseVector([0.9341, 0.0659])],
#  [200067, 243032, DenseVector([0.9341, 0.0659])],
#  [200067, 131043, DenseVector([0.9341, 0.0659])],
#  [200069, 8669, DenseVector([0.9341, 0.0659])],
#  [200069, 131703, DenseVector([0.9341, 0.0659])],
#  [200069, 125825, DenseVector([0.9341, 0.0659])],
#  [200069, 248957, DenseVector([0.9341, 0.0659])],
#  [200069, 10794, DenseVector([0.9341, 0.0659])],
#  [200069, 218715, DenseVector([0.9341, 0.0659])],
#  [200070, 104207, DenseVector([0.9341, 0.0659])],
#  [200070, 39252, DenseVector([0.9341, 0.0659])],
#  [200070, 271459, DenseVector([0.9341, 0.0659])],
#  [200070, 191512, DenseVector([0.9341, 0.0659])],
#  [200070, 124239, DenseVector([0.9341, 0.0659])],
#  [200070, 219295, DenseVector([0.9341, 0.0659])],
#  [200071, 110406, DenseVector([0.9341, 0.0659])],
#  [200071, 286617, DenseVector([0.9341, 0.0659])],
#  [200071, 151553, DenseVector([0.9341, 0.0659])],
#  [200071, 291135, DenseVector([0.9341, 0.0659])],
#  [200071, 226251, DenseVector([0.9341, 0.0659])],
#  [200071, 233170, DenseVector([0.9341, 0.0659])],
#  [200072, 128068, DenseVector([0.9341, 0.0659])],
#  [200072, 101141, DenseVector([0.9341, 0.0659])],
#  [200072, 272622, DenseVector([0.9341, 0.0659])],
#  [200072, 29894, DenseVector([0.9341, 0.0659])],
#  [200072, 36641, DenseVector([0.9341, 0.0659])],
#  [200072, 63433, DenseVector([0.9341, 0.0659])],
#  [200073, 30193, DenseVector([0.9341, 0.0659])],
#  [200073, 52063, DenseVector([0.9341, 0.0659])],
#  [200073, 28167, DenseVector([0.9341, 0.0659])],
#  [200073, 277867, DenseVector([0.9341, 0.0659])],
#  [200073, 175274, DenseVector([0.9341, 0.0659])],
#  [200073, 260816, DenseVector([0.9341, 0.0659])],
#  [200074, 269977, DenseVector([0.9341, 0.0659])],
#  [200074, 276467, DenseVector([0.9341, 0.0659])],
#  [200074, 210679, DenseVector([0.9341, 0.0659])],
#  [200074, 38502, DenseVector([0.9341, 0.0659])],
#  [200074, 289311, DenseVector([0.9341, 0.0659])],
#  [200074, 142078, DenseVector([0.9341, 0.0659])],
#  [200077, 112017, DenseVector([0.9341, 0.0659])],
#  [200077, 179993, DenseVector([0.9341, 0.0659])],
#  [200077, 51632, DenseVector([0.9341, 0.0659])],
#  [200077, 98279, DenseVector([0.9341, 0.0659])],
#  [200077, 142715, DenseVector([0.9341, 0.0659])],
#  [200077, 127917, DenseVector([0.9341, 0.0659])],
#  [200081, 73524, DenseVector([0.9341, 0.0659])],
#  [200081, 164949, DenseVector([0.9341, 0.0659])],
#  [200081, 193711, DenseVector([0.9341, 0.0659])],
#  [200081, 207829, DenseVector([0.9341, 0.0659])],
#  [200081, 10062, DenseVector([0.9341, 0.0659])],
#  [200081, 30624, DenseVector([0.9341, 0.0659])],
#  [200083, 38933, DenseVector([0.9341, 0.0659])],
#  [200083, 76639, DenseVector([0.9341, 0.0659])],
#  [200083, 126581, DenseVector([0.9341, 0.0659])],
#  [200083, 106736, DenseVector([0.9341, 0.0659])],
#  [200083, 147920, DenseVector([0.9341, 0.0659])],
#  [200083, 66989, DenseVector([0.9341, 0.0659])],
#  [200084, 56551, DenseVector([0.9341, 0.0659])],
#  [200084, 292483, DenseVector([0.9341, 0.0659])],
#  [200084, 232515, DenseVector([0.9341, 0.0659])],
#  [200084, 93839, DenseVector([0.9341, 0.0659])],
#  [200084, 216153, DenseVector([0.9341, 0.0659])],
#  [200084, 14869, DenseVector([0.9341, 0.0659])],
#  [200085, 49158, DenseVector([0.9341, 0.0659])],
#  [200085, 172871, DenseVector([0.9341, 0.0659])],
#  [200085, 134106, DenseVector([0.9341, 0.0659])],
#  [200085, 284406, DenseVector([0.9341, 0.0659])],
#  [200085, 138809, DenseVector([0.9341, 0.0659])],
#  [200085, 32503, DenseVector([0.9341, 0.0659])],
#  [200096, 16581, DenseVector([0.9341, 0.0659])],
#  [200096, 45935, DenseVector([0.9341, 0.0659])],
#  [200096, 188471, DenseVector([0.9341, 0.0659])],
#  [200096, 68144, DenseVector([0.9341, 0.0659])],
#  [200096, 130934, DenseVector([0.9341, 0.0659])],
#  [200096, 218442, DenseVector([0.9341, 0.0659])],
#  [200098, 285456, DenseVector([0.9341, 0.0659])],
#  [200098, 289558, DenseVector([0.9341, 0.0659])],
#  [200098, 243829, DenseVector([0.9341, 0.0659])],
#  [200098, 278152, DenseVector([0.9341, 0.0659])],
#  [200098, 21220, DenseVector([0.9341, 0.0659])],
#  [200098, 278582, DenseVector([0.9341, 0.0659])],
#  [200099, 173182, DenseVector([0.9341, 0.0659])],
#  [200099, 239473, DenseVector([0.9341, 0.0659])],
#  [200099, 276334, DenseVector([0.9341, 0.0659])],
#  [200099, 41892, DenseVector([0.9341, 0.0659])],
#  [200099, 85375, DenseVector([0.9341, 0.0659])],
#  [200099, 159970, DenseVector([0.9341, 0.0659])],
#  [200100, 143734, DenseVector([0.9341, 0.0659])],
#  [200100, 29345, DenseVector([0.9341, 0.0659])],
#  [200100, 274810, DenseVector([0.9341, 0.0659])],
#  [200100, 37816, DenseVector([0.9341, 0.0659])],
#  [200100, 10628, DenseVector([0.9341, 0.0659])],
#  [200100, 173495, DenseVector([0.9341, 0.0659])],
#  [200101, 156642, DenseVector([0.9341, 0.0659])],
#  [200101, 103861, DenseVector([0.9341, 0.0659])],
#  [200101, 203386, DenseVector([0.9341, 0.0659])],
#  [200101, 251902, DenseVector([0.9341, 0.0659])],
#  [200101, 228077, DenseVector([0.9341, 0.0659])],
#  [200101, 239984, DenseVector([0.9341, 0.0659])],
#  [200104, 1066, DenseVector([0.9341, 0.0659])],
#  [200104, 38453, DenseVector([0.9341, 0.0659])],
#  [200104, 191718, DenseVector([0.9341, 0.0659])],
#  [200104, 112280, DenseVector([0.9341, 0.0659])],
#  [200104, 99178, DenseVector([0.9341, 0.0659])],
#  [200104, 282514, DenseVector([0.9341, 0.0659])],
#  [200105, 157843, DenseVector([0.9341, 0.0659])],
#  [200105, 20968, DenseVector([0.9341, 0.0659])],
#  [200105, 179956, DenseVector([0.9341, 0.0659])],
#  [200105, 150250, DenseVector([0.9341, 0.0659])],
#  [200105, 85659, DenseVector([0.9341, 0.0659])],
#  [200105, 152229, DenseVector([0.9341, 0.0659])],
#  [200106, 67182, DenseVector([0.9341, 0.0659])],
#  [200106, 181408, DenseVector([0.9341, 0.0659])],
#  [200106, 67509, DenseVector([0.9341, 0.0659])],
#  [200106, 72517, DenseVector([0.9341, 0.0659])],
#  [200106, 84948, DenseVector([0.9341, 0.0659])],
#  [200106, 152491, DenseVector([0.9341, 0.0659])],
#  [200112, 24444, DenseVector([0.9341, 0.0659])],
#  [200112, 107026, DenseVector([0.9341, 0.0659])],
#  [200112, 100877, DenseVector([0.9341, 0.0659])],
#  [200112, 182869, DenseVector([0.9341, 0.0659])],
#  [200112, 71923, DenseVector([0.9341, 0.0659])],
#  [200112, 255284, DenseVector([0.9341, 0.0659])],
#  [200116, 149496, DenseVector([0.9341, 0.0659])],
#  [200116, 126940, DenseVector([0.9341, 0.0659])],
#  [200116, 80138, DenseVector([0.9341, 0.0659])],
#  [200116, 288583, DenseVector([0.9341, 0.0659])],
#  [200116, 106102, DenseVector([0.9341, 0.0659])],
#  [200116, 272638, DenseVector([0.9341, 0.0659])],
#  [200117, 111183, DenseVector([0.9341, 0.0659])],
#  [200117, 118407, DenseVector([0.9341, 0.0659])],
#  [200117, 221371, DenseVector([0.9341, 0.0659])],
#  [200117, 215325, DenseVector([0.9341, 0.0659])],
#  [200117, 29256, DenseVector([0.9341, 0.0659])],
#  [200117, 159641, DenseVector([0.9341, 0.0659])],
#  [200118, 63358, DenseVector([0.9341, 0.0659])],
#  [200118, 284107, DenseVector([0.9341, 0.0659])],
#  [200118, 77125, DenseVector([0.9341, 0.0659])],
#  [200118, 240379, DenseVector([0.9341, 0.0659])],
#  [200118, 243335, DenseVector([0.9341, 0.0659])],
#  [200118, 153923, DenseVector([0.9341, 0.0659])],
#  [200124, 78157, DenseVector([0.9341, 0.0659])],
#  [200124, 162126, DenseVector([0.9341, 0.0659])],
#  [200124, 284066, DenseVector([0.9341, 0.0659])],
#  [200124, 158428, DenseVector([0.9341, 0.0659])],
#  [200124, 280405, DenseVector([0.9341, 0.0659])],
#  [200124, 112595, DenseVector([0.9341, 0.0659])],
#  [200126, 157702, DenseVector([0.9341, 0.0659])],
#  [200126, 263539, DenseVector([0.9341, 0.0659])],
#  [200126, 157784, DenseVector([0.9341, 0.0659])],
#  [200126, 174788, DenseVector([0.9341, 0.0659])],
#  [200126, 141773, DenseVector([0.9341, 0.0659])],
#  [200126, 57701, DenseVector([0.9341, 0.0659])],
#  [200127, 159548, DenseVector([0.9341, 0.0659])],
#  [200127, 70524, DenseVector([0.9341, 0.0659])],
#  [200127, 180109, DenseVector([0.9341, 0.0659])],
#  [200127, 115656, DenseVector([0.9341, 0.0659])],
#  [200127, 10453, DenseVector([0.9341, 0.0659])],
#  [200127, 150618, DenseVector([0.9341, 0.0659])],
#  [200128, 62961, DenseVector([0.9341, 0.0659])],
#  [200128, 285837, DenseVector([0.9341, 0.0659])],
#  [200128, 129803, DenseVector([0.9341, 0.0659])],
#  [200128, 141637, DenseVector([0.9341, 0.0659])],
#  [200128, 208113, DenseVector([0.9341, 0.0659])],
#  [200128, 105251, DenseVector([0.9341, 0.0659])],
#  [200138, 189306, DenseVector([0.9341, 0.0659])],
#  [200138, 190567, DenseVector([0.9341, 0.0659])],
#  [200138, 66946, DenseVector([0.9341, 0.0659])],
#  [200138, 293300, DenseVector([0.9341, 0.0659])],
#  [200138, 201191, DenseVector([0.9341, 0.0659])],
#  [200138, 151866, DenseVector([0.9341, 0.0659])],
#  [200140, 214979, DenseVector([0.9341, 0.0659])],
#  [200140, 283715, DenseVector([0.9341, 0.0659])],
#  [200140, 210549, DenseVector([0.9341, 0.0659])],
#  [200140, 159580, DenseVector([0.9341, 0.0659])],
#  [200140, 2578, DenseVector([0.9341, 0.0659])],
#  [200140, 158633, DenseVector([0.9341, 0.0659])],
#  [200141, 229894, DenseVector([0.9341, 0.0659])],
#  [200141, 250273, DenseVector([0.9341, 0.0659])],
#  [200141, 178659, DenseVector([0.9341, 0.0659])],
#  [200141, 120563, DenseVector([0.9341, 0.0659])],
#  [200141, 201191, DenseVector([0.9341, 0.0659])],
#  [200141, 47420, DenseVector([0.9341, 0.0659])],
#  [200143, 8486, DenseVector([0.9341, 0.0659])],
#  [200143, 187136, DenseVector([0.9341, 0.0659])],
#  [200143, 216914, DenseVector([0.9341, 0.0659])],
#  [200143, 131171, DenseVector([0.9341, 0.0659])],
#  [200143, 51859, DenseVector([0.9341, 0.0659])],
#  [200143, 273031, DenseVector([0.9341, 0.0659])],
#  [200145, 168855, DenseVector([0.9341, 0.0659])],
#  [200145, 89740, DenseVector([0.9341, 0.0659])],
#  [200145, 255196, DenseVector([0.9341, 0.0659])],
#  [200145, 59168, DenseVector([0.9341, 0.0659])],
#  [200145, 164892, DenseVector([0.9341, 0.0659])],
#  [200145, 232758, DenseVector([0.9341, 0.0659])],
#  [200148, 16367, DenseVector([0.9341, 0.0659])],
#  [200148, 144472, DenseVector([0.9341, 0.0659])],
#  [200148, 138863, DenseVector([0.9341, 0.0659])],
#  [200148, 40651, DenseVector([0.9341, 0.0659])],
#  [200148, 159549, DenseVector([0.9341, 0.0659])],
#  [200148, 72771, DenseVector([0.9341, 0.0659])],
#  [200151, 33126, DenseVector([0.9341, 0.0659])],
#  [200151, 23938, DenseVector([0.9341, 0.0659])],
#  [200151, 213415, DenseVector([0.9341, 0.0659])],
#  [200151, 78176, DenseVector([0.9341, 0.0659])],
#  [200151, 170506, DenseVector([0.9341, 0.0659])],
#  [200151, 177409, DenseVector([0.9341, 0.0659])],
#  [200152, 255924, DenseVector([0.9341, 0.0659])],
#  [200152, 187117, DenseVector([0.9341, 0.0659])],
#  [200152, 193934, DenseVector([0.9341, 0.0659])],
#  [200152, 20736, DenseVector([0.9341, 0.0659])],
#  [200152, 210372, DenseVector([0.9341, 0.0659])],
#  [200152, 225472, DenseVector([0.9341, 0.0659])],
#  [200154, 14467, DenseVector([0.9341, 0.0659])],
#  [200154, 46390, DenseVector([0.9341, 0.0659])],
#  [200154, 56423, DenseVector([0.9341, 0.0659])],
#  [200154, 255924, DenseVector([0.9341, 0.0659])],
#  [200154, 152033, DenseVector([0.9341, 0.0659])],
#  [200154, 183027, DenseVector([0.9341, 0.0659])],
#  [200155, 160843, DenseVector([0.9341, 0.0659])],
#  [200155, 257449, DenseVector([0.9341, 0.0659])],
#  [200155, 14995, DenseVector([0.9341, 0.0659])],
#  [200155, 4359, DenseVector([0.9341, 0.0659])],
#  [200155, 134877, DenseVector([0.9341, 0.0659])],
#  [200155, 113416, DenseVector([0.9341, 0.0659])],
#  [200156, 249323, DenseVector([0.9341, 0.0659])],
#  [200156, 270454, DenseVector([0.9341, 0.0659])],
#  [200156, 133594, DenseVector([0.9341, 0.0659])],
#  [200156, 201706, DenseVector([0.9341, 0.0659])],
#  [200156, 94893, DenseVector([0.9341, 0.0659])],
#  [200156, 70945, DenseVector([0.9341, 0.0659])],
#  [200158, 275149, DenseVector([0.9341, 0.0659])],
#  [200158, 286433, DenseVector([0.9341, 0.0659])],
#  [200158, 146448, DenseVector([0.9341, 0.0659])],
#  [200158, 177585, DenseVector([0.9341, 0.0659])],
#  [200158, 128066, DenseVector([0.9341, 0.0659])],
#  [200158, 214871, DenseVector([0.9341, 0.0659])],
#  [200159, 238869, DenseVector([0.9341, 0.0659])],
#  [200159, 211335, DenseVector([0.9341, 0.0659])],
#  [200159, 279176, DenseVector([0.9341, 0.0659])],
#  [200159, 26075, DenseVector([0.9341, 0.0659])],
#  [200159, 206537, DenseVector([0.9341, 0.0659])],
#  [200159, 274931, DenseVector([0.9341, 0.0659])],
#  [200160, 173982, DenseVector([0.9341, 0.0659])],
#  [200160, 191762, DenseVector([0.9341, 0.0659])],
#  [200160, 111151, DenseVector([0.9341, 0.0659])],
#  [200160, 293195, DenseVector([0.9341, 0.0659])],
#  [200160, 231680, DenseVector([0.9341, 0.0659])],
#  [200160, 103933, DenseVector([0.9341, 0.0659])],
#  [200162, 227617, DenseVector([0.9341, 0.0659])],
#  [200162, 211864, DenseVector([0.9341, 0.0659])],
#  [200162, 171714, DenseVector([0.9341, 0.0659])],
#  [200162, 204679, DenseVector([0.9341, 0.0659])],
#  [200162, 131352, DenseVector([0.9341, 0.0659])],
#  [200162, 57671, DenseVector([0.9341, 0.0659])],
#  [200163, 5852, DenseVector([0.9341, 0.0659])],
#  [200163, 31440, DenseVector([0.9341, 0.0659])],
#  [200163, 216055, DenseVector([0.9341, 0.0659])],
#  [200163, 90370, DenseVector([0.9341, 0.0659])],
#  [200163, 113841, DenseVector([0.9341, 0.0659])],
#  [200163, 82698, DenseVector([0.9341, 0.0659])],
#  [200165, 244256, DenseVector([0.9341, 0.0659])],
#  [200165, 226077, DenseVector([0.9341, 0.0659])],
#  [200165, 235981, DenseVector([0.9341, 0.0659])],
#  [200165, 54084, DenseVector([0.9341, 0.0659])],
#  [200165, 46922, DenseVector([0.9341, 0.0659])],
#  [200165, 118861, DenseVector([0.9341, 0.0659])],
#  [200166, 193878, DenseVector([0.9341, 0.0659])],
#  [200166, 152465, DenseVector([0.9341, 0.0659])],
#  [200166, 282686, DenseVector([0.9341, 0.0659])],
#  [200166, 58283, DenseVector([0.9341, 0.0659])],
#  [200166, 249972, DenseVector([0.9341, 0.0659])],
#  [200166, 49989, DenseVector([0.9341, 0.0659])],
#  [200168, 33106, DenseVector([0.9341, 0.0659])],
#  [200168, 170773, DenseVector([0.9341, 0.0659])],
#  [200168, 40055, DenseVector([0.9341, 0.0659])],
#  [200168, 121501, DenseVector([0.9341, 0.0659])],
#  [200168, 226576, DenseVector([0.9341, 0.0659])],
#  [200168, 75322, DenseVector([0.9341, 0.0659])],
#  [200173, 153297, DenseVector([0.9341, 0.0659])],
#  [200173, 293022, DenseVector([0.9341, 0.0659])],
#  [200173, 255190, DenseVector([0.9341, 0.0659])],
#  [200173, 232699, DenseVector([0.9341, 0.0659])],
#  [200173, 288329, DenseVector([0.9341, 0.0659])],
#  [200173, 118642, DenseVector([0.9341, 0.0659])],
#  [200174, 94893, DenseVector([0.9341, 0.0659])],
#  [200174, 137908, DenseVector([0.9341, 0.0659])],
#  [200174, 87687, DenseVector([0.9341, 0.0659])],
#  [200174, 281141, DenseVector([0.9341, 0.0659])],
#  [200174, 106183, DenseVector([0.9341, 0.0659])],
#  [200174, 96153, DenseVector([0.9341, 0.0659])],
#  [200176, 74079, DenseVector([0.9341, 0.0659])],
#  [200176, 141029, DenseVector([0.9341, 0.0659])],
#  [200176, 216094, DenseVector([0.9341, 0.0659])],
#  [200176, 213072, DenseVector([0.9341, 0.0659])],
#  [200176, 213238, DenseVector([0.9341, 0.0659])],
#  [200176, 135745, DenseVector([0.9341, 0.0659])],
#  [200179, 13, DenseVector([0.9341, 0.0659])],
#  [200179, 203607, DenseVector([0.9341, 0.0659])],
#  [200179, 145146, DenseVector([0.9341, 0.0659])],
#  [200179, 131564, DenseVector([0.9341, 0.0659])],
#  [200179, 59296, DenseVector([0.9341, 0.0659])],
#  [200179, 75833, DenseVector([0.9341, 0.0659])],
#  [200182, 198544, DenseVector([0.9341, 0.0659])],
#  [200182, 121002, DenseVector([0.9341, 0.0659])],
#  [200182, 295485, DenseVector([0.9341, 0.0659])],
#  [200182, 145607, DenseVector([0.9341, 0.0659])],
#  [200182, 219744, DenseVector([0.9341, 0.0659])],
#  [200182, 274874, DenseVector([0.9341, 0.0659])],
#  [200186, 141772, DenseVector([0.9341, 0.0659])],
#  [200186, 291044, DenseVector([0.9341, 0.0659])],
#  [200186, 56317, DenseVector([0.9341, 0.0659])],
#  [200186, 205730, DenseVector([0.9341, 0.0659])],
#  [200186, 69847, DenseVector([0.9341, 0.0659])],
#  [200186, 185363, DenseVector([0.9341, 0.0659])],
#  [200191, 225926, DenseVector([0.9341, 0.0659])],
#  [200191, 216514, DenseVector([0.9341, 0.0659])],
#  [200191, 129085, DenseVector([0.9341, 0.0659])],
#  [200191, 156250, DenseVector([0.9341, 0.0659])],
#  ...]

# %%
import csv
with open("GBTC.csv", "w") as output_file:
    writer = csv.writer(output_file)
    writer.writerow(["TrackID", "Predictor"])
    for line in output:
        if line[2][0] == 0.9341221756527832:
            item = [str(line[0]) + "_" + str(line[1]), 0]
        else:
            item = [str(line[0]) + "_" + str(line[1]), 1]
        writer.writerow(item)

# %%
file = open("GBTC.txt", "w")
for line in output:
    file.write(str(line[0])+","+str(line[1])+","+str(line[2][0])+"\n")

# %%
output
# Out:
# [[199810, 208019, DenseVector([0.9341, 0.0659])],
#  [199810, 74139, DenseVector([0.9341, 0.0659])],
#  [199810, 9903, DenseVector([0.9341, 0.0659])],
#  [199810, 242681, DenseVector([0.9341, 0.0659])],
#  [199810, 18515, DenseVector([0.9341, 0.0659])],
#  [199810, 105760, DenseVector([0.9341, 0.0659])],
#  [199812, 276940, DenseVector([0.9341, 0.0659])],
#  [199812, 142408, DenseVector([0.9341, 0.0659])],
#  [199812, 130023, DenseVector([0.9341, 0.0659])],
#  [199812, 29189, DenseVector([0.9341, 0.0659])],
#  [199812, 223706, DenseVector([0.9341, 0.0659])],
#  [199812, 211361, DenseVector([0.9341, 0.0659])],
#  [199813, 188441, DenseVector([0.9341, 0.0659])],
#  [199813, 20968, DenseVector([0.9341, 0.0659])],
#  [199813, 21571, DenseVector([0.9341, 0.0659])],
#  [199813, 79640, DenseVector([0.9341, 0.0659])],
#  [199813, 184173, DenseVector([0.9341, 0.0659])],
#  [199813, 111874, DenseVector([0.9341, 0.0659])],
#  [199814, 122375, DenseVector([0.9341, 0.0659])],
#  [199814, 189043, DenseVector([0.9341, 0.0659])],
#  [199814, 122429, DenseVector([0.9341, 0.0659])],
#  [199814, 52519, DenseVector([0.9341, 0.0659])],
#  [199814, 232332, DenseVector([0.9341, 0.0659])],
#  [199814, 262193, DenseVector([0.9341, 0.0659])],
#  [199815, 64345, DenseVector([0.9341, 0.0659])],
#  [199815, 118841, DenseVector([0.9341, 0.0659])],
#  [199815, 275682, DenseVector([0.9341, 0.0659])],
#  [199815, 30062, DenseVector([0.9341, 0.0659])],
#  [199815, 258473, DenseVector([0.9341, 0.0659])],
#  [199815, 129866, DenseVector([0.9341, 0.0659])],
#  [199816, 274758, DenseVector([0.9341, 0.0659])],
#  [199816, 102153, DenseVector([0.9341, 0.0659])],
#  [199816, 183464, DenseVector([0.9341, 0.0659])],
#  [199816, 23616, DenseVector([0.9341, 0.0659])],
#  [199816, 81699, DenseVector([0.9341, 0.0659])],
#  [199816, 46627, DenseVector([0.9341, 0.0659])],
#  [199817, 83722, DenseVector([0.9341, 0.0659])],
#  [199817, 200166, DenseVector([0.9341, 0.0659])],
#  [199817, 148603, DenseVector([0.9341, 0.0659])],
#  [199817, 88745, DenseVector([0.9341, 0.0659])],
#  [199817, 144775, DenseVector([0.9341, 0.0659])],
#  [199817, 222966, DenseVector([0.9341, 0.0659])],
#  [199818, 141875, DenseVector([0.9341, 0.0659])],
#  [199818, 290905, DenseVector([0.9341, 0.0659])],
#  [199818, 59789, DenseVector([0.9341, 0.0659])],
#  [199818, 283698, DenseVector([0.9341, 0.0659])],
#  [199818, 106788, DenseVector([0.9341, 0.0659])],
#  [199818, 235999, DenseVector([0.9341, 0.0659])],
#  [199819, 202308, DenseVector([0.9341, 0.0659])],
#  [199819, 36793, DenseVector([0.9341, 0.0659])],
#  [199819, 247549, DenseVector([0.9341, 0.0659])],
#  [199819, 214280, DenseVector([0.9341, 0.0659])],
#  [199819, 123424, DenseVector([0.9341, 0.0659])],
#  [199819, 193003, DenseVector([0.9341, 0.0659])],
#  [199820, 235240, DenseVector([0.9341, 0.0659])],
#  [199820, 292341, DenseVector([0.9341, 0.0659])],
#  [199820, 126082, DenseVector([0.9341, 0.0659])],
#  [199820, 142163, DenseVector([0.9341, 0.0659])],
#  [199820, 20067, DenseVector([0.9341, 0.0659])],
#  [199820, 286335, DenseVector([0.9341, 0.0659])],
#  [199821, 231569, DenseVector([0.9341, 0.0659])],
#  [199821, 51933, DenseVector([0.9341, 0.0659])],
#  [199821, 16949, DenseVector([0.9341, 0.0659])],
#  [199821, 34642, DenseVector([0.9341, 0.0659])],
#  [199821, 229894, DenseVector([0.9341, 0.0659])],
#  [199821, 42811, DenseVector([0.9341, 0.0659])],
#  [199822, 47402, DenseVector([0.9341, 0.0659])],
#  [199822, 21317, DenseVector([0.9341, 0.0659])],
#  [199822, 185734, DenseVector([0.9341, 0.0659])],
#  [199822, 92685, DenseVector([0.9341, 0.0659])],
#  [199822, 110099, DenseVector([0.9341, 0.0659])],
#  [199822, 33495, DenseVector([0.9341, 0.0659])],
#  [199823, 21593, DenseVector([0.9341, 0.0659])],
#  [199823, 132124, DenseVector([0.9341, 0.0659])],
#  [199823, 170625, DenseVector([0.9341, 0.0659])],
#  [199823, 30365, DenseVector([0.9341, 0.0659])],
#  [199823, 143570, DenseVector([0.9341, 0.0659])],
#  [199823, 254625, DenseVector([0.9341, 0.0659])],
#  [199824, 281826, DenseVector([0.9341, 0.0659])],
#  [199824, 253265, DenseVector([0.9341, 0.0659])],
#  [199824, 48891, DenseVector([0.9341, 0.0659])],
#  [199824, 33980, DenseVector([0.9341, 0.0659])],
#  [199824, 207963, DenseVector([0.9341, 0.0659])],
#  [199824, 126528, DenseVector([0.9341, 0.0659])],
#  [199826, 48808, DenseVector([0.9341, 0.0659])],
#  [199826, 223958, DenseVector([0.9341, 0.0659])],
#  [199826, 179298, DenseVector([0.9341, 0.0659])],
#  [199826, 5121, DenseVector([0.9341, 0.0659])],
#  [199826, 31975, DenseVector([0.9341, 0.0659])],
#  [199826, 38775, DenseVector([0.9341, 0.0659])],
#  [199827, 92599, DenseVector([0.9341, 0.0659])],
#  [199827, 75369, DenseVector([0.9341, 0.0659])],
#  [199827, 184197, DenseVector([0.9341, 0.0659])],
#  [199827, 183841, DenseVector([0.9341, 0.0659])],
#  [199827, 197936, DenseVector([0.9341, 0.0659])],
#  [199827, 138391, DenseVector([0.9341, 0.0659])],
#  [199830, 36027, DenseVector([0.9341, 0.0659])],
#  [199830, 29249, DenseVector([0.9341, 0.0659])],
#  [199830, 221237, DenseVector([0.9341, 0.0659])],
#  [199830, 123579, DenseVector([0.9341, 0.0659])],
#  [199830, 19694, DenseVector([0.9341, 0.0659])],
#  [199830, 255036, DenseVector([0.9341, 0.0659])],
#  [199838, 6143, DenseVector([0.9341, 0.0659])],
#  [199838, 24607, DenseVector([0.9341, 0.0659])],
#  [199838, 95726, DenseVector([0.9341, 0.0659])],
#  [199838, 46697, DenseVector([0.9341, 0.0659])],
#  [199838, 256209, DenseVector([0.9341, 0.0659])],
#  [199838, 266780, DenseVector([0.9341, 0.0659])],
#  [199839, 7477, DenseVector([0.9341, 0.0659])],
#  [199839, 266143, DenseVector([0.9341, 0.0659])],
#  [199839, 291820, DenseVector([0.9341, 0.0659])],
#  [199839, 196470, DenseVector([0.9341, 0.0659])],
#  [199839, 263222, DenseVector([0.9341, 0.0659])],
#  [199839, 225097, DenseVector([0.9341, 0.0659])],
#  [199844, 77700, DenseVector([0.9341, 0.0659])],
#  [199844, 138272, DenseVector([0.9341, 0.0659])],
#  [199844, 140229, DenseVector([0.9341, 0.0659])],
#  [199844, 43472, DenseVector([0.9341, 0.0659])],
#  [199844, 118108, DenseVector([0.9341, 0.0659])],
#  [199844, 81165, DenseVector([0.9341, 0.0659])],
#  [199845, 189985, DenseVector([0.9341, 0.0659])],
#  [199845, 31440, DenseVector([0.9341, 0.0659])],
#  [199845, 169945, DenseVector([0.9341, 0.0659])],
#  [199845, 95594, DenseVector([0.9341, 0.0659])],
#  [199845, 238400, DenseVector([0.9341, 0.0659])],
#  [199845, 100669, DenseVector([0.9341, 0.0659])],
#  [199846, 273378, DenseVector([0.9341, 0.0659])],
#  [199846, 19705, DenseVector([0.9341, 0.0659])],
#  [199846, 20499, DenseVector([0.9341, 0.0659])],
#  [199846, 101984, DenseVector([0.9341, 0.0659])],
#  [199846, 214726, DenseVector([0.9341, 0.0659])],
#  [199846, 61792, DenseVector([0.9341, 0.0659])],
#  [199847, 44444, DenseVector([0.9341, 0.0659])],
#  [199847, 39446, DenseVector([0.9341, 0.0659])],
#  [199847, 282901, DenseVector([0.9341, 0.0659])],
#  [199847, 63072, DenseVector([0.9341, 0.0659])],
#  [199847, 19595, DenseVector([0.9341, 0.0659])],
#  [199847, 127769, DenseVector([0.9341, 0.0659])],
#  [199853, 54037, DenseVector([0.9341, 0.0659])],
#  [199853, 89981, DenseVector([0.9341, 0.0659])],
#  [199853, 256134, DenseVector([0.9341, 0.0659])],
#  [199853, 213546, DenseVector([0.9341, 0.0659])],
#  [199853, 222196, DenseVector([0.9341, 0.0659])],
#  [199853, 161111, DenseVector([0.9341, 0.0659])],
#  [199854, 226277, DenseVector([0.9341, 0.0659])],
#  [199854, 92910, DenseVector([0.9341, 0.0659])],
#  [199854, 214592, DenseVector([0.9341, 0.0659])],
#  [199854, 20999, DenseVector([0.9341, 0.0659])],
#  [199854, 154755, DenseVector([0.9341, 0.0659])],
#  [199854, 228397, DenseVector([0.9341, 0.0659])],
#  [199855, 252693, DenseVector([0.9341, 0.0659])],
#  [199855, 69487, DenseVector([0.9341, 0.0659])],
#  [199855, 24631, DenseVector([0.9341, 0.0659])],
#  [199855, 50032, DenseVector([0.9341, 0.0659])],
#  [199855, 277150, DenseVector([0.9341, 0.0659])],
#  [199855, 4836, DenseVector([0.9341, 0.0659])],
#  [199858, 142462, DenseVector([0.9341, 0.0659])],
#  [199858, 255065, DenseVector([0.9341, 0.0659])],
#  [199858, 85596, DenseVector([0.9341, 0.0659])],
#  [199858, 269486, DenseVector([0.9341, 0.0659])],
#  [199858, 30595, DenseVector([0.9341, 0.0659])],
#  [199858, 37731, DenseVector([0.9341, 0.0659])],
#  [199859, 22400, DenseVector([0.9341, 0.0659])],
#  [199859, 105128, DenseVector([0.9341, 0.0659])],
#  [199859, 2877, DenseVector([0.9341, 0.0659])],
#  [199859, 51667, DenseVector([0.9341, 0.0659])],
#  [199859, 289911, DenseVector([0.9341, 0.0659])],
#  [199859, 17, DenseVector([0.9341, 0.0659])],
#  [199861, 192584, DenseVector([0.9341, 0.0659])],
#  [199861, 56525, DenseVector([0.9341, 0.0659])],
#  [199861, 94381, DenseVector([0.9341, 0.0659])],
#  [199861, 249701, DenseVector([0.9341, 0.0659])],
#  [199861, 127111, DenseVector([0.9341, 0.0659])],
#  [199861, 77154, DenseVector([0.9341, 0.0659])],
#  [199862, 80123, DenseVector([0.9341, 0.0659])],
#  [199862, 108161, DenseVector([0.9341, 0.0659])],
#  [199862, 179298, DenseVector([0.9341, 0.0659])],
#  [199862, 280411, DenseVector([0.9341, 0.0659])],
#  [199862, 196729, DenseVector([0.9341, 0.0659])],
#  [199862, 225847, DenseVector([0.9341, 0.0659])],
#  [199863, 222604, DenseVector([0.9341, 0.0659])],
#  [199863, 126413, DenseVector([0.9341, 0.0659])],
#  [199863, 144718, DenseVector([0.9341, 0.0659])],
#  [199863, 241999, DenseVector([0.9341, 0.0659])],
#  [199863, 184020, DenseVector([0.9341, 0.0659])],
#  [199863, 249930, DenseVector([0.9341, 0.0659])],
#  [199866, 142729, DenseVector([0.9341, 0.0659])],
#  [199866, 117929, DenseVector([0.9341, 0.0659])],
#  [199866, 252600, DenseVector([0.9341, 0.0659])],
#  [199866, 125126, DenseVector([0.9341, 0.0659])],
#  [199866, 46889, DenseVector([0.9341, 0.0659])],
#  [199866, 291314, DenseVector([0.9341, 0.0659])],
#  [199868, 24085, DenseVector([0.9341, 0.0659])],
#  [199868, 80589, DenseVector([0.9341, 0.0659])],
#  [199868, 79604, DenseVector([0.9341, 0.0659])],
#  [199868, 218286, DenseVector([0.9341, 0.0659])],
#  [199868, 122067, DenseVector([0.9341, 0.0659])],
#  [199868, 257899, DenseVector([0.9341, 0.0659])],
#  [199873, 8379, DenseVector([0.9341, 0.0659])],
#  [199873, 217580, DenseVector([0.9341, 0.0659])],
#  [199873, 65230, DenseVector([0.9341, 0.0659])],
#  [199873, 65855, DenseVector([0.9341, 0.0659])],
#  [199873, 241597, DenseVector([0.9341, 0.0659])],
#  [199873, 187050, DenseVector([0.9341, 0.0659])],
#  [199876, 257097, DenseVector([0.9341, 0.0659])],
#  [199876, 277360, DenseVector([0.9341, 0.0659])],
#  [199876, 69317, DenseVector([0.9341, 0.0659])],
#  [199876, 47894, DenseVector([0.9341, 0.0659])],
#  [199876, 102449, DenseVector([0.9341, 0.0659])],
#  [199876, 267088, DenseVector([0.9341, 0.0659])],
#  [199880, 266143, DenseVector([0.9341, 0.0659])],
#  [199880, 224615, DenseVector([0.9341, 0.0659])],
#  [199880, 154327, DenseVector([0.9341, 0.0659])],
#  [199880, 14107, DenseVector([0.9341, 0.0659])],
#  [199880, 22640, DenseVector([0.9341, 0.0659])],
#  [199880, 133341, DenseVector([0.9341, 0.0659])],
#  [199882, 146575, DenseVector([0.9341, 0.0659])],
#  [199882, 192238, DenseVector([0.9341, 0.0659])],
#  [199882, 109824, DenseVector([0.9341, 0.0659])],
#  [199882, 125958, DenseVector([0.9341, 0.0659])],
#  [199882, 79309, DenseVector([0.9341, 0.0659])],
#  [199882, 42782, DenseVector([0.9341, 0.0659])],
#  [199884, 36155, DenseVector([0.9341, 0.0659])],
#  [199884, 5444, DenseVector([0.9341, 0.0659])],
#  [199884, 150640, DenseVector([0.9341, 0.0659])],
#  [199884, 155463, DenseVector([0.9341, 0.0659])],
#  [199884, 247800, DenseVector([0.9341, 0.0659])],
#  [199884, 152366, DenseVector([0.9341, 0.0659])],
#  [199886, 134307, DenseVector([0.9341, 0.0659])],
#  [199886, 255399, DenseVector([0.9341, 0.0659])],
#  [199886, 155743, DenseVector([0.9341, 0.0659])],
#  [199886, 151269, DenseVector([0.9341, 0.0659])],
#  [199886, 200432, DenseVector([0.9341, 0.0659])],
#  [199886, 87913, DenseVector([0.9341, 0.0659])],
#  [199890, 114634, DenseVector([0.9341, 0.0659])],
#  [199890, 151926, DenseVector([0.9341, 0.0659])],
#  [199890, 190001, DenseVector([0.9341, 0.0659])],
#  [199890, 286440, DenseVector([0.9341, 0.0659])],
#  [199890, 48289, DenseVector([0.9341, 0.0659])],
#  [199890, 141713, DenseVector([0.9341, 0.0659])],
#  [199891, 32135, DenseVector([0.9341, 0.0659])],
#  [199891, 244657, DenseVector([0.9341, 0.0659])],
#  [199891, 117789, DenseVector([0.9341, 0.0659])],
#  [199891, 45103, DenseVector([0.9341, 0.0659])],
#  [199891, 279606, DenseVector([0.9341, 0.0659])],
#  [199891, 280110, DenseVector([0.9341, 0.0659])],
#  [199894, 279067, DenseVector([0.9341, 0.0659])],
#  [199894, 15811, DenseVector([0.9341, 0.0659])],
#  [199894, 250006, DenseVector([0.9341, 0.0659])],
#  [199894, 31746, DenseVector([0.9341, 0.0659])],
#  [199894, 251949, DenseVector([0.9341, 0.0659])],
#  [199894, 9592, DenseVector([0.9341, 0.0659])],
#  [199895, 195551, DenseVector([0.9341, 0.0659])],
#  [199895, 69797, DenseVector([0.9341, 0.0659])],
#  [199895, 59891, DenseVector([0.9341, 0.0659])],
#  [199895, 249919, DenseVector([0.9341, 0.0659])],
#  [199895, 229468, DenseVector([0.9341, 0.0659])],
#  [199895, 276415, DenseVector([0.9341, 0.0659])],
#  [199896, 175151, DenseVector([0.9341, 0.0659])],
#  [199896, 101756, DenseVector([0.9341, 0.0659])],
#  [199896, 222456, DenseVector([0.9341, 0.0659])],
#  [199896, 183890, DenseVector([0.9341, 0.0659])],
#  [199896, 42748, DenseVector([0.9341, 0.0659])],
#  [199896, 59296, DenseVector([0.9341, 0.0659])],
#  [199899, 30902, DenseVector([0.9341, 0.0659])],
#  [199899, 54300, DenseVector([0.9341, 0.0659])],
#  [199899, 46394, DenseVector([0.9341, 0.0659])],
#  [199899, 236744, DenseVector([0.9341, 0.0659])],
#  [199899, 40880, DenseVector([0.9341, 0.0659])],
#  [199899, 210352, DenseVector([0.9341, 0.0659])],
#  [199900, 219739, DenseVector([0.9341, 0.0659])],
#  [199900, 287949, DenseVector([0.9341, 0.0659])],
#  [199900, 23822, DenseVector([0.9341, 0.0659])],
#  [199900, 44210, DenseVector([0.9341, 0.0659])],
#  [199900, 261886, DenseVector([0.9341, 0.0659])],
#  [199900, 110099, DenseVector([0.9341, 0.0659])],
#  [199902, 111243, DenseVector([0.9341, 0.0659])],
#  [199902, 124466, DenseVector([0.9341, 0.0659])],
#  [199902, 263958, DenseVector([0.9341, 0.0659])],
#  [199902, 249140, DenseVector([0.9341, 0.0659])],
#  [199902, 298, DenseVector([0.9341, 0.0659])],
#  [199902, 127445, DenseVector([0.9341, 0.0659])],
#  [199907, 64481, DenseVector([0.9341, 0.0659])],
#  [199907, 61826, DenseVector([0.9341, 0.0659])],
#  [199907, 54636, DenseVector([0.9341, 0.0659])],
#  [199907, 52391, DenseVector([0.9341, 0.0659])],
#  [199907, 172050, DenseVector([0.9341, 0.0659])],
#  [199907, 78355, DenseVector([0.9341, 0.0659])],
#  [199911, 152843, DenseVector([0.9341, 0.0659])],
#  [199911, 23252, DenseVector([0.9341, 0.0659])],
#  [199911, 170920, DenseVector([0.9341, 0.0659])],
#  [199911, 21878, DenseVector([0.9341, 0.0659])],
#  [199911, 50179, DenseVector([0.9341, 0.0659])],
#  [199911, 229538, DenseVector([0.9341, 0.0659])],
#  [199912, 252021, DenseVector([0.9341, 0.0659])],
#  [199912, 125831, DenseVector([0.9341, 0.0659])],
#  [199912, 233293, DenseVector([0.9341, 0.0659])],
#  [199912, 286721, DenseVector([0.9341, 0.0659])],
#  [199912, 87357, DenseVector([0.9341, 0.0659])],
#  [199912, 188926, DenseVector([0.9341, 0.0659])],
#  [199914, 284745, DenseVector([0.9341, 0.0659])],
#  [199914, 137479, DenseVector([0.9341, 0.0659])],
#  [199914, 94531, DenseVector([0.9341, 0.0659])],
#  [199914, 295555, DenseVector([0.9341, 0.0659])],
#  [199914, 262472, DenseVector([0.9341, 0.0659])],
#  [199914, 78278, DenseVector([0.9341, 0.0659])],
#  [199915, 118642, DenseVector([0.9341, 0.0659])],
#  [199915, 252839, DenseVector([0.9341, 0.0659])],
#  [199915, 232361, DenseVector([0.9341, 0.0659])],
#  [199915, 11535, DenseVector([0.9341, 0.0659])],
#  [199915, 266171, DenseVector([0.9341, 0.0659])],
#  [199915, 29554, DenseVector([0.9341, 0.0659])],
#  [199918, 251164, DenseVector([0.9341, 0.0659])],
#  [199918, 114265, DenseVector([0.9341, 0.0659])],
#  [199918, 103426, DenseVector([0.9341, 0.0659])],
#  [199918, 138333, DenseVector([0.9341, 0.0659])],
#  [199918, 150958, DenseVector([0.9341, 0.0659])],
#  [199918, 242417, DenseVector([0.9341, 0.0659])],
#  [199920, 237580, DenseVector([0.9341, 0.0659])],
#  [199920, 138590, DenseVector([0.9341, 0.0659])],
#  [199920, 77933, DenseVector([0.9341, 0.0659])],
#  [199920, 247578, DenseVector([0.9341, 0.0659])],
#  [199920, 144100, DenseVector([0.9341, 0.0659])],
#  [199920, 106344, DenseVector([0.9341, 0.0659])],
#  [199921, 48891, DenseVector([0.9341, 0.0659])],
#  [199921, 175928, DenseVector([0.9341, 0.0659])],
#  [199921, 143902, DenseVector([0.9341, 0.0659])],
#  [199921, 95242, DenseVector([0.9341, 0.0659])],
#  [199921, 198864, DenseVector([0.9341, 0.0659])],
#  [199921, 76816, DenseVector([0.9341, 0.0659])],
#  [199924, 108161, DenseVector([0.9341, 0.0659])],
#  [199924, 16078, DenseVector([0.9341, 0.0659])],
#  [199924, 120535, DenseVector([0.9341, 0.0659])],
#  [199924, 54651, DenseVector([0.9341, 0.0659])],
#  [199924, 49904, DenseVector([0.9341, 0.0659])],
#  [199924, 62568, DenseVector([0.9341, 0.0659])],
#  [199926, 142473, DenseVector([0.9341, 0.0659])],
#  [199926, 180224, DenseVector([0.9341, 0.0659])],
#  [199926, 73940, DenseVector([0.9341, 0.0659])],
#  [199926, 44783, DenseVector([0.9341, 0.0659])],
#  [199926, 139444, DenseVector([0.9341, 0.0659])],
#  [199926, 41368, DenseVector([0.9341, 0.0659])],
#  [199928, 137693, DenseVector([0.9341, 0.0659])],
#  [199928, 87125, DenseVector([0.9341, 0.0659])],
#  [199928, 171481, DenseVector([0.9341, 0.0659])],
#  [199928, 251278, DenseVector([0.9341, 0.0659])],
#  [199928, 65142, DenseVector([0.9341, 0.0659])],
#  [199928, 215837, DenseVector([0.9341, 0.0659])],
#  [199931, 140334, DenseVector([0.9341, 0.0659])],
#  [199931, 90442, DenseVector([0.9341, 0.0659])],
#  [199931, 161183, DenseVector([0.9341, 0.0659])],
#  [199931, 242657, DenseVector([0.9341, 0.0659])],
#  [199931, 149874, DenseVector([0.9341, 0.0659])],
#  [199931, 122518, DenseVector([0.9341, 0.0659])],
#  [199932, 131954, DenseVector([0.9341, 0.0659])],
#  [199932, 68360, DenseVector([0.9341, 0.0659])],
#  [199932, 119027, DenseVector([0.9341, 0.0659])],
#  [199932, 284320, DenseVector([0.9341, 0.0659])],
#  [199932, 104542, DenseVector([0.9341, 0.0659])],
#  [199932, 2924, DenseVector([0.9341, 0.0659])],
#  [199934, 222840, DenseVector([0.9341, 0.0659])],
#  [199934, 18198, DenseVector([0.9341, 0.0659])],
#  [199934, 37960, DenseVector([0.9341, 0.0659])],
#  [199934, 250816, DenseVector([0.9341, 0.0659])],
#  [199934, 170214, DenseVector([0.9341, 0.0659])],
#  [199934, 44222, DenseVector([0.9341, 0.0659])],
#  [199936, 32596, DenseVector([0.9341, 0.0659])],
#  [199936, 12969, DenseVector([0.9341, 0.0659])],
#  [199936, 216902, DenseVector([0.9341, 0.0659])],
#  [199936, 89110, DenseVector([0.9341, 0.0659])],
#  [199936, 71574, DenseVector([0.9341, 0.0659])],
#  [199936, 245276, DenseVector([0.9341, 0.0659])],
#  [199937, 20538, DenseVector([0.9341, 0.0659])],
#  [199937, 151964, DenseVector([0.9341, 0.0659])],
#  [199937, 171735, DenseVector([0.9341, 0.0659])],
#  [199937, 163166, DenseVector([0.9341, 0.0659])],
#  [199937, 95326, DenseVector([0.9341, 0.0659])],
#  [199937, 270004, DenseVector([0.9341, 0.0659])],
#  [199939, 111062, DenseVector([0.9341, 0.0659])],
#  [199939, 223859, DenseVector([0.9341, 0.0659])],
#  [199939, 165847, DenseVector([0.9341, 0.0659])],
#  [199939, 245574, DenseVector([0.9341, 0.0659])],
#  [199939, 171700, DenseVector([0.9341, 0.0659])],
#  [199939, 12922, DenseVector([0.9341, 0.0659])],
#  [199941, 135759, DenseVector([0.9341, 0.0659])],
#  [199941, 261128, DenseVector([0.9341, 0.0659])],
#  [199941, 220067, DenseVector([0.9341, 0.0659])],
#  [199941, 191060, DenseVector([0.9341, 0.0659])],
#  [199941, 45668, DenseVector([0.9341, 0.0659])],
#  [199941, 92843, DenseVector([0.9341, 0.0659])],
#  [199944, 67182, DenseVector([0.9341, 0.0659])],
#  [199944, 281157, DenseVector([0.9341, 0.0659])],
#  [199944, 18733, DenseVector([0.9341, 0.0659])],
#  [199944, 166911, DenseVector([0.9341, 0.0659])],
#  [199944, 181496, DenseVector([0.9341, 0.0659])],
#  [199944, 118642, DenseVector([0.9341, 0.0659])],
#  [199947, 107099, DenseVector([0.9341, 0.0659])],
#  [199947, 99698, DenseVector([0.9341, 0.0659])],
#  [199947, 196040, DenseVector([0.9341, 0.0659])],
#  [199947, 52853, DenseVector([0.9341, 0.0659])],
#  [199947, 19388, DenseVector([0.9341, 0.0659])],
#  [199947, 163568, DenseVector([0.9341, 0.0659])],
#  [199949, 157403, DenseVector([0.9341, 0.0659])],
#  [199949, 262177, DenseVector([0.9341, 0.0659])],
#  [199949, 187117, DenseVector([0.9341, 0.0659])],
#  [199949, 73710, DenseVector([0.9341, 0.0659])],
#  [199949, 157478, DenseVector([0.9341, 0.0659])],
#  [199949, 48583, DenseVector([0.9341, 0.0659])],
#  [199954, 44782, DenseVector([0.9341, 0.0659])],
#  [199954, 75676, DenseVector([0.9341, 0.0659])],
#  [199954, 144640, DenseVector([0.9341, 0.0659])],
#  [199954, 277674, DenseVector([0.9341, 0.0659])],
#  [199954, 85063, DenseVector([0.9341, 0.0659])],
#  [199954, 92599, DenseVector([0.9341, 0.0659])],
#  [199955, 264558, DenseVector([0.9341, 0.0659])],
#  [199955, 224104, DenseVector([0.9341, 0.0659])],
#  [199955, 267631, DenseVector([0.9341, 0.0659])],
#  [199955, 152820, DenseVector([0.9341, 0.0659])],
#  [199955, 99223, DenseVector([0.9341, 0.0659])],
#  [199955, 111277, DenseVector([0.9341, 0.0659])],
#  [199958, 248267, DenseVector([0.9341, 0.0659])],
#  [199958, 202112, DenseVector([0.9341, 0.0659])],
#  [199958, 7740, DenseVector([0.9341, 0.0659])],
#  [199958, 263828, DenseVector([0.9341, 0.0659])],
#  [199958, 37057, DenseVector([0.9341, 0.0659])],
#  [199958, 43391, DenseVector([0.9341, 0.0659])],
#  [199961, 72011, DenseVector([0.9341, 0.0659])],
#  [199961, 85844, DenseVector([0.9341, 0.0659])],
#  [199961, 17790, DenseVector([0.9341, 0.0659])],
#  [199961, 12010, DenseVector([0.9341, 0.0659])],
#  [199961, 203948, DenseVector([0.9341, 0.0659])],
#  [199961, 44094, DenseVector([0.9341, 0.0659])],
#  [199962, 14689, DenseVector([0.9341, 0.0659])],
#  [199962, 39799, DenseVector([0.9341, 0.0659])],
#  [199962, 39602, DenseVector([0.9341, 0.0659])],
#  [199962, 38287, DenseVector([0.9341, 0.0659])],
#  [199962, 63433, DenseVector([0.9341, 0.0659])],
#  [199962, 250006, DenseVector([0.9341, 0.0659])],
#  [199963, 202739, DenseVector([0.9341, 0.0659])],
#  [199963, 214979, DenseVector([0.9341, 0.0659])],
#  [199963, 2843, DenseVector([0.9341, 0.0659])],
#  [199963, 132003, DenseVector([0.9341, 0.0659])],
#  [199963, 183159, DenseVector([0.9341, 0.0659])],
#  [199963, 222425, DenseVector([0.9341, 0.0659])],
#  [199966, 94498, DenseVector([0.9341, 0.0659])],
#  [199966, 85844, DenseVector([0.9341, 0.0659])],
#  [199966, 17907, DenseVector([0.9341, 0.0659])],
#  [199966, 6173, DenseVector([0.9341, 0.0659])],
#  [199966, 156103, DenseVector([0.9341, 0.0659])],
#  [199966, 4310, DenseVector([0.9341, 0.0659])],
#  [199973, 9810, DenseVector([0.9341, 0.0659])],
#  [199973, 143588, DenseVector([0.9341, 0.0659])],
#  [199973, 257449, DenseVector([0.9341, 0.0659])],
#  [199973, 39447, DenseVector([0.9341, 0.0659])],
#  [199973, 204267, DenseVector([0.9341, 0.0659])],
#  [199973, 172907, DenseVector([0.9341, 0.0659])],
#  [199974, 295907, DenseVector([0.9341, 0.0659])],
#  [199974, 10628, DenseVector([0.9341, 0.0659])],
#  [199974, 286329, DenseVector([0.9341, 0.0659])],
#  [199974, 73886, DenseVector([0.9341, 0.0659])],
#  [199974, 70203, DenseVector([0.9341, 0.0659])],
#  [199974, 282197, DenseVector([0.9341, 0.0659])],
#  [199976, 125958, DenseVector([0.9341, 0.0659])],
#  [199976, 138333, DenseVector([0.9341, 0.0659])],
#  [199976, 63855, DenseVector([0.9341, 0.0659])],
#  [199976, 88123, DenseVector([0.9341, 0.0659])],
#  [199976, 188301, DenseVector([0.9341, 0.0659])],
#  [199976, 116957, DenseVector([0.9341, 0.0659])],
#  [199977, 293108, DenseVector([0.9341, 0.0659])],
#  [199977, 211659, DenseVector([0.9341, 0.0659])],
#  [199977, 61827, DenseVector([0.9341, 0.0659])],
#  [199977, 12127, DenseVector([0.9341, 0.0659])],
#  [199977, 153742, DenseVector([0.9341, 0.0659])],
#  [199977, 281844, DenseVector([0.9341, 0.0659])],
#  [199981, 244686, DenseVector([0.9341, 0.0659])],
#  [199981, 190154, DenseVector([0.9341, 0.0659])],
#  [199981, 206026, DenseVector([0.9341, 0.0659])],
#  [199981, 260780, DenseVector([0.9341, 0.0659])],
#  [199981, 142675, DenseVector([0.9341, 0.0659])],
#  [199981, 154382, DenseVector([0.9341, 0.0659])],
#  [199982, 220973, DenseVector([0.9341, 0.0659])],
#  [199982, 79550, DenseVector([0.9341, 0.0659])],
#  [199982, 183431, DenseVector([0.9341, 0.0659])],
#  [199982, 114059, DenseVector([0.9341, 0.0659])],
#  [199982, 120535, DenseVector([0.9341, 0.0659])],
#  [199982, 189306, DenseVector([0.9341, 0.0659])],
#  [199983, 240746, DenseVector([0.9341, 0.0659])],
#  [199983, 163720, DenseVector([0.9341, 0.0659])],
#  [199983, 6330, DenseVector([0.9341, 0.0659])],
#  [199983, 47483, DenseVector([0.9341, 0.0659])],
#  [199983, 4102, DenseVector([0.9341, 0.0659])],
#  [199983, 245818, DenseVector([0.9341, 0.0659])],
#  [199984, 199756, DenseVector([0.9341, 0.0659])],
#  [199984, 66754, DenseVector([0.9341, 0.0659])],
#  [199984, 268182, DenseVector([0.9341, 0.0659])],
#  [199984, 197751, DenseVector([0.9341, 0.0659])],
#  [199984, 135194, DenseVector([0.9341, 0.0659])],
#  [199984, 254703, DenseVector([0.9341, 0.0659])],
#  [199989, 174481, DenseVector([0.9341, 0.0659])],
#  [199989, 133167, DenseVector([0.9341, 0.0659])],
#  [199989, 184197, DenseVector([0.9341, 0.0659])],
#  [199989, 145221, DenseVector([0.9341, 0.0659])],
#  [199989, 70738, DenseVector([0.9341, 0.0659])],
#  [199989, 48244, DenseVector([0.9341, 0.0659])],
#  [199991, 108560, DenseVector([0.9341, 0.0659])],
#  [199991, 152985, DenseVector([0.9341, 0.0659])],
#  [199991, 200612, DenseVector([0.9341, 0.0659])],
#  [199991, 18684, DenseVector([0.9341, 0.0659])],
#  [199991, 32651, DenseVector([0.9341, 0.0659])],
#  [199991, 247852, DenseVector([0.9341, 0.0659])],
#  [199996, 75564, DenseVector([0.9341, 0.0659])],
#  [199996, 154321, DenseVector([0.9341, 0.0659])],
#  [199996, 61539, DenseVector([0.9341, 0.0659])],
#  [199996, 44110, DenseVector([0.9341, 0.0659])],
#  [199996, 237168, DenseVector([0.9341, 0.0659])],
#  [199996, 58813, DenseVector([0.9341, 0.0659])],
#  [199997, 210679, DenseVector([0.9341, 0.0659])],
#  [199997, 5791, DenseVector([0.9341, 0.0659])],
#  [199997, 233951, DenseVector([0.9341, 0.0659])],
#  [199997, 12756, DenseVector([0.9341, 0.0659])],
#  [199997, 37154, DenseVector([0.9341, 0.0659])],
#  [199997, 215013, DenseVector([0.9341, 0.0659])],
#  [200000, 28885, DenseVector([0.9341, 0.0659])],
#  [200000, 245668, DenseVector([0.9341, 0.0659])],
#  [200000, 66741, DenseVector([0.9341, 0.0659])],
#  [200000, 61924, DenseVector([0.9341, 0.0659])],
#  [200000, 156098, DenseVector([0.9341, 0.0659])],
#  [200000, 275159, DenseVector([0.9341, 0.0659])],
#  [200008, 104154, DenseVector([0.9341, 0.0659])],
#  [200008, 46876, DenseVector([0.9341, 0.0659])],
#  [200008, 256560, DenseVector([0.9341, 0.0659])],
#  [200008, 67905, DenseVector([0.9341, 0.0659])],
#  [200008, 1139, DenseVector([0.9341, 0.0659])],
#  [200008, 141686, DenseVector([0.9341, 0.0659])],
#  [200011, 12596, DenseVector([0.9341, 0.0659])],
#  [200011, 9135, DenseVector([0.9341, 0.0659])],
#  [200011, 120099, DenseVector([0.9341, 0.0659])],
#  [200011, 34204, DenseVector([0.9341, 0.0659])],
#  [200011, 206993, DenseVector([0.9341, 0.0659])],
#  [200011, 185400, DenseVector([0.9341, 0.0659])],
#  [200015, 238871, DenseVector([0.9341, 0.0659])],
#  [200015, 231629, DenseVector([0.9341, 0.0659])],
#  [200015, 232699, DenseVector([0.9341, 0.0659])],
#  [200015, 42375, DenseVector([0.9341, 0.0659])],
#  [200015, 288583, DenseVector([0.9341, 0.0659])],
#  [200015, 291248, DenseVector([0.9341, 0.0659])],
#  [200017, 214205, DenseVector([0.9341, 0.0659])],
#  [200017, 69801, DenseVector([0.9341, 0.0659])],
#  [200017, 172315, DenseVector([0.9341, 0.0659])],
#  [200017, 237086, DenseVector([0.9341, 0.0659])],
#  [200017, 248372, DenseVector([0.9341, 0.0659])],
#  [200017, 250952, DenseVector([0.9341, 0.0659])],
#  [200020, 160977, DenseVector([0.9341, 0.0659])],
#  [200020, 102918, DenseVector([0.9341, 0.0659])],
#  [200020, 35714, DenseVector([0.9341, 0.0659])],
#  [200020, 177509, DenseVector([0.9341, 0.0659])],
#  [200020, 21102, DenseVector([0.9341, 0.0659])],
#  [200020, 254344, DenseVector([0.9341, 0.0659])],
#  [200022, 78599, DenseVector([0.9341, 0.0659])],
#  [200022, 69145, DenseVector([0.9341, 0.0659])],
#  [200022, 14434, DenseVector([0.9341, 0.0659])],
#  [200022, 251839, DenseVector([0.9341, 0.0659])],
#  [200022, 52131, DenseVector([0.9341, 0.0659])],
#  [200022, 201326, DenseVector([0.9341, 0.0659])],
#  [200024, 65495, DenseVector([0.9341, 0.0659])],
#  [200024, 256187, DenseVector([0.9341, 0.0659])],
#  [200024, 38735, DenseVector([0.9341, 0.0659])],
#  [200024, 142844, DenseVector([0.9341, 0.0659])],
#  [200024, 206527, DenseVector([0.9341, 0.0659])],
#  [200024, 202088, DenseVector([0.9341, 0.0659])],
#  [200031, 30877, DenseVector([0.9341, 0.0659])],
#  [200031, 8244, DenseVector([0.9341, 0.0659])],
#  [200031, 130183, DenseVector([0.9341, 0.0659])],
#  [200031, 198762, DenseVector([0.9341, 0.0659])],
#  [200031, 34503, DenseVector([0.9341, 0.0659])],
#  [200031, 227283, DenseVector([0.9341, 0.0659])],
#  [200032, 218377, DenseVector([0.9341, 0.0659])],
#  [200032, 110262, DenseVector([0.9341, 0.0659])],
#  [200032, 18681, DenseVector([0.9341, 0.0659])],
#  [200032, 138493, DenseVector([0.9341, 0.0659])],
#  [200032, 64167, DenseVector([0.9341, 0.0659])],
#  [200032, 22820, DenseVector([0.9341, 0.0659])],
#  [200033, 238637, DenseVector([0.9341, 0.0659])],
#  [200033, 280510, DenseVector([0.9341, 0.0659])],
#  [200033, 81561, DenseVector([0.9341, 0.0659])],
#  [200033, 154323, DenseVector([0.9341, 0.0659])],
#  [200033, 246110, DenseVector([0.9341, 0.0659])],
#  [200033, 115430, DenseVector([0.9341, 0.0659])],
#  [200034, 59870, DenseVector([0.9341, 0.0659])],
#  [200034, 258228, DenseVector([0.9341, 0.0659])],
#  [200034, 57481, DenseVector([0.9341, 0.0659])],
#  [200034, 289146, DenseVector([0.9341, 0.0659])],
#  [200034, 193705, DenseVector([0.9341, 0.0659])],
#  [200034, 216403, DenseVector([0.9341, 0.0659])],
#  [200039, 33786, DenseVector([0.9341, 0.0659])],
#  [200039, 93820, DenseVector([0.9341, 0.0659])],
#  [200039, 158950, DenseVector([0.9341, 0.0659])],
#  [200039, 129597, DenseVector([0.9341, 0.0659])],
#  [200039, 64855, DenseVector([0.9341, 0.0659])],
#  [200039, 9222, DenseVector([0.9341, 0.0659])],
#  [200042, 52853, DenseVector([0.9341, 0.0659])],
#  [200042, 155158, DenseVector([0.9341, 0.0659])],
#  [200042, 110558, DenseVector([0.9341, 0.0659])],
#  [200042, 174226, DenseVector([0.9341, 0.0659])],
#  [200042, 160629, DenseVector([0.9341, 0.0659])],
#  [200042, 97838, DenseVector([0.9341, 0.0659])],
#  [200044, 276970, DenseVector([0.9341, 0.0659])],
#  [200044, 144465, DenseVector([0.9341, 0.0659])],
#  [200044, 237953, DenseVector([0.9341, 0.0659])],
#  [200044, 273540, DenseVector([0.9341, 0.0659])],
#  [200044, 65494, DenseVector([0.9341, 0.0659])],
#  [200044, 237561, DenseVector([0.9341, 0.0659])],
#  [200045, 278533, DenseVector([0.9341, 0.0659])],
#  [200045, 36514, DenseVector([0.9341, 0.0659])],
#  [200045, 192445, DenseVector([0.9341, 0.0659])],
#  [200045, 5114, DenseVector([0.9341, 0.0659])],
#  [200045, 206449, DenseVector([0.9341, 0.0659])],
#  [200045, 172949, DenseVector([0.9341, 0.0659])],
#  [200046, 153923, DenseVector([0.9341, 0.0659])],
#  [200046, 82066, DenseVector([0.9341, 0.0659])],
#  [200046, 106788, DenseVector([0.9341, 0.0659])],
#  [200046, 234917, DenseVector([0.9341, 0.0659])],
#  [200046, 232322, DenseVector([0.9341, 0.0659])],
#  [200046, 7858, DenseVector([0.9341, 0.0659])],
#  [200049, 140281, DenseVector([0.9341, 0.0659])],
#  [200049, 68473, DenseVector([0.9341, 0.0659])],
#  [200049, 110918, DenseVector([0.9341, 0.0659])],
#  [200049, 262523, DenseVector([0.9341, 0.0659])],
#  [200049, 146264, DenseVector([0.9341, 0.0659])],
#  [200049, 63340, DenseVector([0.9341, 0.0659])],
#  [200053, 275356, DenseVector([0.9341, 0.0659])],
#  [200053, 224601, DenseVector([0.9341, 0.0659])],
#  [200053, 266176, DenseVector([0.9341, 0.0659])],
#  [200053, 266936, DenseVector([0.9341, 0.0659])],
#  [200053, 236876, DenseVector([0.9341, 0.0659])],
#  [200053, 248056, DenseVector([0.9341, 0.0659])],
#  [200054, 258428, DenseVector([0.9341, 0.0659])],
#  [200054, 155798, DenseVector([0.9341, 0.0659])],
#  [200054, 196987, DenseVector([0.9341, 0.0659])],
#  [200054, 241475, DenseVector([0.9341, 0.0659])],
#  [200054, 198197, DenseVector([0.9341, 0.0659])],
#  [200054, 153172, DenseVector([0.9341, 0.0659])],
#  [200055, 52198, DenseVector([0.9341, 0.0659])],
#  [200055, 233815, DenseVector([0.9341, 0.0659])],
#  [200055, 175557, DenseVector([0.9341, 0.0659])],
#  [200055, 59101, DenseVector([0.9341, 0.0659])],
#  [200055, 56695, DenseVector([0.9341, 0.0659])],
#  [200055, 134398, DenseVector([0.9341, 0.0659])],
#  [200061, 96084, DenseVector([0.9341, 0.0659])],
#  [200061, 79655, DenseVector([0.9341, 0.0659])],
#  [200061, 87277, DenseVector([0.9341, 0.0659])],
#  [200061, 137432, DenseVector([0.9341, 0.0659])],
#  [200061, 126448, DenseVector([0.9341, 0.0659])],
#  [200061, 165136, DenseVector([0.9341, 0.0659])],
#  [200062, 409, DenseVector([0.9341, 0.0659])],
#  [200062, 274169, DenseVector([0.9341, 0.0659])],
#  [200062, 34583, DenseVector([0.9341, 0.0659])],
#  [200062, 267994, DenseVector([0.9341, 0.0659])],
#  [200062, 282197, DenseVector([0.9341, 0.0659])],
#  [200062, 120246, DenseVector([0.9341, 0.0659])],
#  [200063, 197591, DenseVector([0.9341, 0.0659])],
#  [200063, 65494, DenseVector([0.9341, 0.0659])],
#  [200063, 279986, DenseVector([0.9341, 0.0659])],
#  [200063, 1779, DenseVector([0.9341, 0.0659])],
#  [200063, 39137, DenseVector([0.9341, 0.0659])],
#  [200063, 237564, DenseVector([0.9341, 0.0659])],
#  [200065, 179571, DenseVector([0.9341, 0.0659])],
#  [200065, 196286, DenseVector([0.9341, 0.0659])],
#  [200065, 26875, DenseVector([0.9341, 0.0659])],
#  [200065, 119451, DenseVector([0.9341, 0.0659])],
#  [200065, 227397, DenseVector([0.9341, 0.0659])],
#  [200065, 243829, DenseVector([0.9341, 0.0659])],
#  [200066, 252312, DenseVector([0.9341, 0.0659])],
#  [200066, 214595, DenseVector([0.9341, 0.0659])],
#  [200066, 247413, DenseVector([0.9341, 0.0659])],
#  [200066, 163568, DenseVector([0.9341, 0.0659])],
#  [200066, 133542, DenseVector([0.9341, 0.0659])],
#  [200066, 281136, DenseVector([0.9341, 0.0659])],
#  [200067, 10177, DenseVector([0.9341, 0.0659])],
#  [200067, 50554, DenseVector([0.9341, 0.0659])],
#  [200067, 238616, DenseVector([0.9341, 0.0659])],
#  [200067, 174122, DenseVector([0.9341, 0.0659])],
#  [200067, 243032, DenseVector([0.9341, 0.0659])],
#  [200067, 131043, DenseVector([0.9341, 0.0659])],
#  [200069, 8669, DenseVector([0.9341, 0.0659])],
#  [200069, 131703, DenseVector([0.9341, 0.0659])],
#  [200069, 125825, DenseVector([0.9341, 0.0659])],
#  [200069, 248957, DenseVector([0.9341, 0.0659])],
#  [200069, 10794, DenseVector([0.9341, 0.0659])],
#  [200069, 218715, DenseVector([0.9341, 0.0659])],
#  [200070, 104207, DenseVector([0.9341, 0.0659])],
#  [200070, 39252, DenseVector([0.9341, 0.0659])],
#  [200070, 271459, DenseVector([0.9341, 0.0659])],
#  [200070, 191512, DenseVector([0.9341, 0.0659])],
#  [200070, 124239, DenseVector([0.9341, 0.0659])],
#  [200070, 219295, DenseVector([0.9341, 0.0659])],
#  [200071, 110406, DenseVector([0.9341, 0.0659])],
#  [200071, 286617, DenseVector([0.9341, 0.0659])],
#  [200071, 151553, DenseVector([0.9341, 0.0659])],
#  [200071, 291135, DenseVector([0.9341, 0.0659])],
#  [200071, 226251, DenseVector([0.9341, 0.0659])],
#  [200071, 233170, DenseVector([0.9341, 0.0659])],
#  [200072, 128068, DenseVector([0.9341, 0.0659])],
#  [200072, 101141, DenseVector([0.9341, 0.0659])],
#  [200072, 272622, DenseVector([0.9341, 0.0659])],
#  [200072, 29894, DenseVector([0.9341, 0.0659])],
#  [200072, 36641, DenseVector([0.9341, 0.0659])],
#  [200072, 63433, DenseVector([0.9341, 0.0659])],
#  [200073, 30193, DenseVector([0.9341, 0.0659])],
#  [200073, 52063, DenseVector([0.9341, 0.0659])],
#  [200073, 28167, DenseVector([0.9341, 0.0659])],
#  [200073, 277867, DenseVector([0.9341, 0.0659])],
#  [200073, 175274, DenseVector([0.9341, 0.0659])],
#  [200073, 260816, DenseVector([0.9341, 0.0659])],
#  [200074, 269977, DenseVector([0.9341, 0.0659])],
#  [200074, 276467, DenseVector([0.9341, 0.0659])],
#  [200074, 210679, DenseVector([0.9341, 0.0659])],
#  [200074, 38502, DenseVector([0.9341, 0.0659])],
#  [200074, 289311, DenseVector([0.9341, 0.0659])],
#  [200074, 142078, DenseVector([0.9341, 0.0659])],
#  [200077, 112017, DenseVector([0.9341, 0.0659])],
#  [200077, 179993, DenseVector([0.9341, 0.0659])],
#  [200077, 51632, DenseVector([0.9341, 0.0659])],
#  [200077, 98279, DenseVector([0.9341, 0.0659])],
#  [200077, 142715, DenseVector([0.9341, 0.0659])],
#  [200077, 127917, DenseVector([0.9341, 0.0659])],
#  [200081, 73524, DenseVector([0.9341, 0.0659])],
#  [200081, 164949, DenseVector([0.9341, 0.0659])],
#  [200081, 193711, DenseVector([0.9341, 0.0659])],
#  [200081, 207829, DenseVector([0.9341, 0.0659])],
#  [200081, 10062, DenseVector([0.9341, 0.0659])],
#  [200081, 30624, DenseVector([0.9341, 0.0659])],
#  [200083, 38933, DenseVector([0.9341, 0.0659])],
#  [200083, 76639, DenseVector([0.9341, 0.0659])],
#  [200083, 126581, DenseVector([0.9341, 0.0659])],
#  [200083, 106736, DenseVector([0.9341, 0.0659])],
#  [200083, 147920, DenseVector([0.9341, 0.0659])],
#  [200083, 66989, DenseVector([0.9341, 0.0659])],
#  [200084, 56551, DenseVector([0.9341, 0.0659])],
#  [200084, 292483, DenseVector([0.9341, 0.0659])],
#  [200084, 232515, DenseVector([0.9341, 0.0659])],
#  [200084, 93839, DenseVector([0.9341, 0.0659])],
#  [200084, 216153, DenseVector([0.9341, 0.0659])],
#  [200084, 14869, DenseVector([0.9341, 0.0659])],
#  [200085, 49158, DenseVector([0.9341, 0.0659])],
#  [200085, 172871, DenseVector([0.9341, 0.0659])],
#  [200085, 134106, DenseVector([0.9341, 0.0659])],
#  [200085, 284406, DenseVector([0.9341, 0.0659])],
#  [200085, 138809, DenseVector([0.9341, 0.0659])],
#  [200085, 32503, DenseVector([0.9341, 0.0659])],
#  [200096, 16581, DenseVector([0.9341, 0.0659])],
#  [200096, 45935, DenseVector([0.9341, 0.0659])],
#  [200096, 188471, DenseVector([0.9341, 0.0659])],
#  [200096, 68144, DenseVector([0.9341, 0.0659])],
#  [200096, 130934, DenseVector([0.9341, 0.0659])],
#  [200096, 218442, DenseVector([0.9341, 0.0659])],
#  [200098, 285456, DenseVector([0.9341, 0.0659])],
#  [200098, 289558, DenseVector([0.9341, 0.0659])],
#  [200098, 243829, DenseVector([0.9341, 0.0659])],
#  [200098, 278152, DenseVector([0.9341, 0.0659])],
#  [200098, 21220, DenseVector([0.9341, 0.0659])],
#  [200098, 278582, DenseVector([0.9341, 0.0659])],
#  [200099, 173182, DenseVector([0.9341, 0.0659])],
#  [200099, 239473, DenseVector([0.9341, 0.0659])],
#  [200099, 276334, DenseVector([0.9341, 0.0659])],
#  [200099, 41892, DenseVector([0.9341, 0.0659])],
#  [200099, 85375, DenseVector([0.9341, 0.0659])],
#  [200099, 159970, DenseVector([0.9341, 0.0659])],
#  [200100, 143734, DenseVector([0.9341, 0.0659])],
#  [200100, 29345, DenseVector([0.9341, 0.0659])],
#  [200100, 274810, DenseVector([0.9341, 0.0659])],
#  [200100, 37816, DenseVector([0.9341, 0.0659])],
#  [200100, 10628, DenseVector([0.9341, 0.0659])],
#  [200100, 173495, DenseVector([0.9341, 0.0659])],
#  [200101, 156642, DenseVector([0.9341, 0.0659])],
#  [200101, 103861, DenseVector([0.9341, 0.0659])],
#  [200101, 203386, DenseVector([0.9341, 0.0659])],
#  [200101, 251902, DenseVector([0.9341, 0.0659])],
#  [200101, 228077, DenseVector([0.9341, 0.0659])],
#  [200101, 239984, DenseVector([0.9341, 0.0659])],
#  [200104, 1066, DenseVector([0.9341, 0.0659])],
#  [200104, 38453, DenseVector([0.9341, 0.0659])],
#  [200104, 191718, DenseVector([0.9341, 0.0659])],
#  [200104, 112280, DenseVector([0.9341, 0.0659])],
#  [200104, 99178, DenseVector([0.9341, 0.0659])],
#  [200104, 282514, DenseVector([0.9341, 0.0659])],
#  [200105, 157843, DenseVector([0.9341, 0.0659])],
#  [200105, 20968, DenseVector([0.9341, 0.0659])],
#  [200105, 179956, DenseVector([0.9341, 0.0659])],
#  [200105, 150250, DenseVector([0.9341, 0.0659])],
#  [200105, 85659, DenseVector([0.9341, 0.0659])],
#  [200105, 152229, DenseVector([0.9341, 0.0659])],
#  [200106, 67182, DenseVector([0.9341, 0.0659])],
#  [200106, 181408, DenseVector([0.9341, 0.0659])],
#  [200106, 67509, DenseVector([0.9341, 0.0659])],
#  [200106, 72517, DenseVector([0.9341, 0.0659])],
#  [200106, 84948, DenseVector([0.9341, 0.0659])],
#  [200106, 152491, DenseVector([0.9341, 0.0659])],
#  [200112, 24444, DenseVector([0.9341, 0.0659])],
#  [200112, 107026, DenseVector([0.9341, 0.0659])],
#  [200112, 100877, DenseVector([0.9341, 0.0659])],
#  [200112, 182869, DenseVector([0.9341, 0.0659])],
#  [200112, 71923, DenseVector([0.9341, 0.0659])],
#  [200112, 255284, DenseVector([0.9341, 0.0659])],
#  [200116, 149496, DenseVector([0.9341, 0.0659])],
#  [200116, 126940, DenseVector([0.9341, 0.0659])],
#  [200116, 80138, DenseVector([0.9341, 0.0659])],
#  [200116, 288583, DenseVector([0.9341, 0.0659])],
#  [200116, 106102, DenseVector([0.9341, 0.0659])],
#  [200116, 272638, DenseVector([0.9341, 0.0659])],
#  [200117, 111183, DenseVector([0.9341, 0.0659])],
#  [200117, 118407, DenseVector([0.9341, 0.0659])],
#  [200117, 221371, DenseVector([0.9341, 0.0659])],
#  [200117, 215325, DenseVector([0.9341, 0.0659])],
#  [200117, 29256, DenseVector([0.9341, 0.0659])],
#  [200117, 159641, DenseVector([0.9341, 0.0659])],
#  [200118, 63358, DenseVector([0.9341, 0.0659])],
#  [200118, 284107, DenseVector([0.9341, 0.0659])],
#  [200118, 77125, DenseVector([0.9341, 0.0659])],
#  [200118, 240379, DenseVector([0.9341, 0.0659])],
#  [200118, 243335, DenseVector([0.9341, 0.0659])],
#  [200118, 153923, DenseVector([0.9341, 0.0659])],
#  [200124, 78157, DenseVector([0.9341, 0.0659])],
#  [200124, 162126, DenseVector([0.9341, 0.0659])],
#  [200124, 284066, DenseVector([0.9341, 0.0659])],
#  [200124, 158428, DenseVector([0.9341, 0.0659])],
#  [200124, 280405, DenseVector([0.9341, 0.0659])],
#  [200124, 112595, DenseVector([0.9341, 0.0659])],
#  [200126, 157702, DenseVector([0.9341, 0.0659])],
#  [200126, 263539, DenseVector([0.9341, 0.0659])],
#  [200126, 157784, DenseVector([0.9341, 0.0659])],
#  [200126, 174788, DenseVector([0.9341, 0.0659])],
#  [200126, 141773, DenseVector([0.9341, 0.0659])],
#  [200126, 57701, DenseVector([0.9341, 0.0659])],
#  [200127, 159548, DenseVector([0.9341, 0.0659])],
#  [200127, 70524, DenseVector([0.9341, 0.0659])],
#  [200127, 180109, DenseVector([0.9341, 0.0659])],
#  [200127, 115656, DenseVector([0.9341, 0.0659])],
#  [200127, 10453, DenseVector([0.9341, 0.0659])],
#  [200127, 150618, DenseVector([0.9341, 0.0659])],
#  [200128, 62961, DenseVector([0.9341, 0.0659])],
#  [200128, 285837, DenseVector([0.9341, 0.0659])],
#  [200128, 129803, DenseVector([0.9341, 0.0659])],
#  [200128, 141637, DenseVector([0.9341, 0.0659])],
#  [200128, 208113, DenseVector([0.9341, 0.0659])],
#  [200128, 105251, DenseVector([0.9341, 0.0659])],
#  [200138, 189306, DenseVector([0.9341, 0.0659])],
#  [200138, 190567, DenseVector([0.9341, 0.0659])],
#  [200138, 66946, DenseVector([0.9341, 0.0659])],
#  [200138, 293300, DenseVector([0.9341, 0.0659])],
#  [200138, 201191, DenseVector([0.9341, 0.0659])],
#  [200138, 151866, DenseVector([0.9341, 0.0659])],
#  [200140, 214979, DenseVector([0.9341, 0.0659])],
#  [200140, 283715, DenseVector([0.9341, 0.0659])],
#  [200140, 210549, DenseVector([0.9341, 0.0659])],
#  [200140, 159580, DenseVector([0.9341, 0.0659])],
#  [200140, 2578, DenseVector([0.9341, 0.0659])],
#  [200140, 158633, DenseVector([0.9341, 0.0659])],
#  [200141, 229894, DenseVector([0.9341, 0.0659])],
#  [200141, 250273, DenseVector([0.9341, 0.0659])],
#  [200141, 178659, DenseVector([0.9341, 0.0659])],
#  [200141, 120563, DenseVector([0.9341, 0.0659])],
#  [200141, 201191, DenseVector([0.9341, 0.0659])],
#  [200141, 47420, DenseVector([0.9341, 0.0659])],
#  [200143, 8486, DenseVector([0.9341, 0.0659])],
#  [200143, 187136, DenseVector([0.9341, 0.0659])],
#  [200143, 216914, DenseVector([0.9341, 0.0659])],
#  [200143, 131171, DenseVector([0.9341, 0.0659])],
#  [200143, 51859, DenseVector([0.9341, 0.0659])],
#  [200143, 273031, DenseVector([0.9341, 0.0659])],
#  [200145, 168855, DenseVector([0.9341, 0.0659])],
#  [200145, 89740, DenseVector([0.9341, 0.0659])],
#  [200145, 255196, DenseVector([0.9341, 0.0659])],
#  [200145, 59168, DenseVector([0.9341, 0.0659])],
#  [200145, 164892, DenseVector([0.9341, 0.0659])],
#  [200145, 232758, DenseVector([0.9341, 0.0659])],
#  [200148, 16367, DenseVector([0.9341, 0.0659])],
#  [200148, 144472, DenseVector([0.9341, 0.0659])],
#  [200148, 138863, DenseVector([0.9341, 0.0659])],
#  [200148, 40651, DenseVector([0.9341, 0.0659])],
#  [200148, 159549, DenseVector([0.9341, 0.0659])],
#  [200148, 72771, DenseVector([0.9341, 0.0659])],
#  [200151, 33126, DenseVector([0.9341, 0.0659])],
#  [200151, 23938, DenseVector([0.9341, 0.0659])],
#  [200151, 213415, DenseVector([0.9341, 0.0659])],
#  [200151, 78176, DenseVector([0.9341, 0.0659])],
#  [200151, 170506, DenseVector([0.9341, 0.0659])],
#  [200151, 177409, DenseVector([0.9341, 0.0659])],
#  [200152, 255924, DenseVector([0.9341, 0.0659])],
#  [200152, 187117, DenseVector([0.9341, 0.0659])],
#  [200152, 193934, DenseVector([0.9341, 0.0659])],
#  [200152, 20736, DenseVector([0.9341, 0.0659])],
#  [200152, 210372, DenseVector([0.9341, 0.0659])],
#  [200152, 225472, DenseVector([0.9341, 0.0659])],
#  [200154, 14467, DenseVector([0.9341, 0.0659])],
#  [200154, 46390, DenseVector([0.9341, 0.0659])],
#  [200154, 56423, DenseVector([0.9341, 0.0659])],
#  [200154, 255924, DenseVector([0.9341, 0.0659])],
#  [200154, 152033, DenseVector([0.9341, 0.0659])],
#  [200154, 183027, DenseVector([0.9341, 0.0659])],
#  [200155, 160843, DenseVector([0.9341, 0.0659])],
#  [200155, 257449, DenseVector([0.9341, 0.0659])],
#  [200155, 14995, DenseVector([0.9341, 0.0659])],
#  [200155, 4359, DenseVector([0.9341, 0.0659])],
#  [200155, 134877, DenseVector([0.9341, 0.0659])],
#  [200155, 113416, DenseVector([0.9341, 0.0659])],
#  [200156, 249323, DenseVector([0.9341, 0.0659])],
#  [200156, 270454, DenseVector([0.9341, 0.0659])],
#  [200156, 133594, DenseVector([0.9341, 0.0659])],
#  [200156, 201706, DenseVector([0.9341, 0.0659])],
#  [200156, 94893, DenseVector([0.9341, 0.0659])],
#  [200156, 70945, DenseVector([0.9341, 0.0659])],
#  [200158, 275149, DenseVector([0.9341, 0.0659])],
#  [200158, 286433, DenseVector([0.9341, 0.0659])],
#  [200158, 146448, DenseVector([0.9341, 0.0659])],
#  [200158, 177585, DenseVector([0.9341, 0.0659])],
#  [200158, 128066, DenseVector([0.9341, 0.0659])],
#  [200158, 214871, DenseVector([0.9341, 0.0659])],
#  [200159, 238869, DenseVector([0.9341, 0.0659])],
#  [200159, 211335, DenseVector([0.9341, 0.0659])],
#  [200159, 279176, DenseVector([0.9341, 0.0659])],
#  [200159, 26075, DenseVector([0.9341, 0.0659])],
#  [200159, 206537, DenseVector([0.9341, 0.0659])],
#  [200159, 274931, DenseVector([0.9341, 0.0659])],
#  [200160, 173982, DenseVector([0.9341, 0.0659])],
#  [200160, 191762, DenseVector([0.9341, 0.0659])],
#  [200160, 111151, DenseVector([0.9341, 0.0659])],
#  [200160, 293195, DenseVector([0.9341, 0.0659])],
#  [200160, 231680, DenseVector([0.9341, 0.0659])],
#  [200160, 103933, DenseVector([0.9341, 0.0659])],
#  [200162, 227617, DenseVector([0.9341, 0.0659])],
#  [200162, 211864, DenseVector([0.9341, 0.0659])],
#  [200162, 171714, DenseVector([0.9341, 0.0659])],
#  [200162, 204679, DenseVector([0.9341, 0.0659])],
#  [200162, 131352, DenseVector([0.9341, 0.0659])],
#  [200162, 57671, DenseVector([0.9341, 0.0659])],
#  [200163, 5852, DenseVector([0.9341, 0.0659])],
#  [200163, 31440, DenseVector([0.9341, 0.0659])],
#  [200163, 216055, DenseVector([0.9341, 0.0659])],
#  [200163, 90370, DenseVector([0.9341, 0.0659])],
#  [200163, 113841, DenseVector([0.9341, 0.0659])],
#  [200163, 82698, DenseVector([0.9341, 0.0659])],
#  [200165, 244256, DenseVector([0.9341, 0.0659])],
#  [200165, 226077, DenseVector([0.9341, 0.0659])],
#  [200165, 235981, DenseVector([0.9341, 0.0659])],
#  [200165, 54084, DenseVector([0.9341, 0.0659])],
#  [200165, 46922, DenseVector([0.9341, 0.0659])],
#  [200165, 118861, DenseVector([0.9341, 0.0659])],
#  [200166, 193878, DenseVector([0.9341, 0.0659])],
#  [200166, 152465, DenseVector([0.9341, 0.0659])],
#  [200166, 282686, DenseVector([0.9341, 0.0659])],
#  [200166, 58283, DenseVector([0.9341, 0.0659])],
#  [200166, 249972, DenseVector([0.9341, 0.0659])],
#  [200166, 49989, DenseVector([0.9341, 0.0659])],
#  [200168, 33106, DenseVector([0.9341, 0.0659])],
#  [200168, 170773, DenseVector([0.9341, 0.0659])],
#  [200168, 40055, DenseVector([0.9341, 0.0659])],
#  [200168, 121501, DenseVector([0.9341, 0.0659])],
#  [200168, 226576, DenseVector([0.9341, 0.0659])],
#  [200168, 75322, DenseVector([0.9341, 0.0659])],
#  [200173, 153297, DenseVector([0.9341, 0.0659])],
#  [200173, 293022, DenseVector([0.9341, 0.0659])],
#  [200173, 255190, DenseVector([0.9341, 0.0659])],
#  [200173, 232699, DenseVector([0.9341, 0.0659])],
#  [200173, 288329, DenseVector([0.9341, 0.0659])],
#  [200173, 118642, DenseVector([0.9341, 0.0659])],
#  [200174, 94893, DenseVector([0.9341, 0.0659])],
#  [200174, 137908, DenseVector([0.9341, 0.0659])],
#  [200174, 87687, DenseVector([0.9341, 0.0659])],
#  [200174, 281141, DenseVector([0.9341, 0.0659])],
#  [200174, 106183, DenseVector([0.9341, 0.0659])],
#  [200174, 96153, DenseVector([0.9341, 0.0659])],
#  [200176, 74079, DenseVector([0.9341, 0.0659])],
#  [200176, 141029, DenseVector([0.9341, 0.0659])],
#  [200176, 216094, DenseVector([0.9341, 0.0659])],
#  [200176, 213072, DenseVector([0.9341, 0.0659])],
#  [200176, 213238, DenseVector([0.9341, 0.0659])],
#  [200176, 135745, DenseVector([0.9341, 0.0659])],
#  [200179, 13, DenseVector([0.9341, 0.0659])],
#  [200179, 203607, DenseVector([0.9341, 0.0659])],
#  [200179, 145146, DenseVector([0.9341, 0.0659])],
#  [200179, 131564, DenseVector([0.9341, 0.0659])],
#  [200179, 59296, DenseVector([0.9341, 0.0659])],
#  [200179, 75833, DenseVector([0.9341, 0.0659])],
#  [200182, 198544, DenseVector([0.9341, 0.0659])],
#  [200182, 121002, DenseVector([0.9341, 0.0659])],
#  [200182, 295485, DenseVector([0.9341, 0.0659])],
#  [200182, 145607, DenseVector([0.9341, 0.0659])],
#  [200182, 219744, DenseVector([0.9341, 0.0659])],
#  [200182, 274874, DenseVector([0.9341, 0.0659])],
#  [200186, 141772, DenseVector([0.9341, 0.0659])],
#  [200186, 291044, DenseVector([0.9341, 0.0659])],
#  [200186, 56317, DenseVector([0.9341, 0.0659])],
#  [200186, 205730, DenseVector([0.9341, 0.0659])],
#  [200186, 69847, DenseVector([0.9341, 0.0659])],
#  [200186, 185363, DenseVector([0.9341, 0.0659])],
#  [200191, 225926, DenseVector([0.9341, 0.0659])],
#  [200191, 216514, DenseVector([0.9341, 0.0659])],
#  [200191, 129085, DenseVector([0.9341, 0.0659])],
#  [200191, 156250, DenseVector([0.9341, 0.0659])],
#  ...]

# %% [markdown]
# #
